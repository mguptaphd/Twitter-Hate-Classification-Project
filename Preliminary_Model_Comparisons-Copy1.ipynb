# %%
from __future__ import print_function

import pandas as pd 
import numpy as np 
import sklearn

# NLTK/NLP
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
import nltk
from nltk import FreqDist, word_tokenize
import string, re
import urllib
from nltk.corpus import stopwords
from gensim.models import word2vec
from nltk.collocations import *
import gensim
from gensim.models import KeyedVectors
from gensim.scripts.glove2word2vec import glove2word2vec


# Classifiers 
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import MultinomialNB
from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier
from xgboost.sklearn import XGBClassifier  

from sklearn.model_selection import RandomizedSearchCV, GridSearchCV

# Metrics
from sklearn import metrics
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report, roc_curve, auc, precision_recall_curve
from sklearn.model_selection import train_test_split
import scikitplot as skplt

#Sampling
from imblearn.pipeline import make_pipeline, Pipeline
from imblearn.over_sampling import SMOTE

#Visualization
import matplotlib.pyplot as plt 
import seaborn as sns
# %matplotlib inline

# miscellaneous
from sklearn.utils import resample
import sklearn.decomposition as decomposition

import warnings 
warnings.filterwarnings("ignore")

import csv
import pickle

# %run my_functions.ipynb

# %%
with open('data/cleaned-reshuffled.pkl', 'rb') as f:
	df = pickle.load(f)

# %%
df.head()
# Out:
#       id  label                                              tweet  \
# 0  29727      0  sad to see the scenes of hooligans pre #engrus...
# 1  14466      0  #gooddyeyoung #yoyoyo  !! super happy to be ap...
# 2  18194      0  queen evil's bihdayð#lnic #lnicjustanevilbd...
# 3  18283      1  @user you might be a libtard if... #libtard  #...
# 4  25845      0  what are your goals? find out here...   #smile...
#
#                                           tidy_tweet  \
# 0  sad to see the scenes of hooligans pre #engrus...
# 1  #gooddyeyoung #yoyoyo super happy to be apa of...
# 2  queen evil s bihday #lnic #lnicjustanevilbday ...
# 3  you might be a libtard if #libtard #sjw #liber...
# 4           what are your goals find out here #smile
#
#                                        no_hash_tweet  \
# 0  sad to see the scenes of hooligans pre engrus ...
# 1  gooddyeyoung yoyoyo super happy to be apa of t...
# 2  queen evil s bihday lnic lnicjustanevilbday bi...
# 3  you might be a libtard if libtard sjw liberal ...
# 4            what are your goals find out here smile
#
#                                      tokenized_tweet  \
# 0  [sad, to, see, the, scenes, of, hooligans, pre...
# 1  [gooddyeyoung, yoyoyo, super, happy, to, be, a...
# 2  [queen, evil, s, bihday, lnic, lnicjustanevilb...
# 3  [you, might, be, a, libtard, if, libtard, sjw,...
# 4   [what, are, your, goals, find, out, here, smile]
#
#                                       stemmed_tokens  \
# 0  [sad, to, see, the, scene, of, hooligan, pre, ...
# 1  [gooddyeyoung, yoyoyo, super, happi, to, be, a...
# 2  [queen, evil, s, bihday, lnic, lnicjustanevilb...
# 3  [you, might, be, a, libtard, if, libtard, sjw,...
# 4    [what, are, your, goal, find, out, here, smile]
#
#                                    lemmatized_tokens  \
# 0  [sad, to, see, the, scene, of, hooligan, pre, ...
# 1  [gooddyeyoung, yoyoyo, super, happy, to, be, a...
# 2  [queen, evil, s, bihday, lnic, lnicjustanevilb...
# 3  [you, might, be, a, libtard, if, libtard, sjw,...
# 4    [what, are, your, goal, find, out, here, smile]
#
#                                            lem_tweet  \
# 0  sad to see the scenes of hooligans pre engrus ...
# 1  gooddyeyoung yoyoyo super happy to be apa of t...
# 2  queen evil s bihday lnic lnicjustanevilbday bi...
# 3  you might be a libtard if libtard sjw liberal ...
# 4            what are your goals find out here smile
#
#                                           stem_tweet
# 0  sad to see the scenes of hooligans pre engrus ...
# 1  gooddyeyoung yoyoyo super happy to be apa of t...
# 2  queen evil s bihday lnic lnicjustanevilbday bi...
# 3  you might be a libtard if libtard sjw liberal ...
# 4             what are your goals find out here smil

# %% [markdown]
# ## Train / Val / Test Split

# %%
X = df.drop(['label'], axis = 1)

# %%
y = df['label']

# %%
#splitting into train and test 
X_model, X_test, y_model, y_test = train_test_split(X, y, stratify = y, test_size=0.20, random_state=123)

# %%
#splitting "model" into training and validation sets
X_train, X_val, y_train, y_val = train_test_split(X_model, y_model, stratify = y_model, test_size=0.20, random_state=123)

# %% [markdown]
# ## Comparing Vectorization and Method Performance

# %%
#initializing vectorizers and creating tuple for wrapper comparison function

count_vect = CountVectorizer(1,1)
count_ngram1_2 = CountVectorizer(1,2)
count_ngram1_3 = CountVectorizer(1,3)

tfidf_vect = TfidfVectorizer(1,1)
tfidf_ngram1_2 = TfidfVectorizer(ngram_range=(1,2))
tfidf_ngram1_3 = TfidfVectorizer(ngram_range=(1,3))

vectorization_list = [('COUNT_VECTORIZER', count_vect),
                      ('COUNT_NGRAM_1_2', count_ngram1_2),
                      ('COUNT_NGRAM_1_3', count_ngram1_3),
                      ('TFIDF_VECTORIZER', tfidf_vect),
                      ('TFIDF_NGRAM_1_2', tfidf_ngram1_2),
                      ('TFIDF_NGRAM_1_3', tfidf_ngram1_3)]

# %% [markdown]
# # Multinomial Naive Bayes (MNB)

# %% [markdown]
# #### Initial Comparision: Multiple Vectorizer and Class Balance Corrections

# %%
np.random.seed(0)

# %%
#MNB with no class balance corrections
nb_results1 = compare_vectorization_model(X_train.lem_tweet, y_train, 
                                   X_val.lem_tweet, y_val, MultinomialNB(), vectorization_list)

nb_results1
# Out:
#                       COUNT_VECTORIZER  COUNT_NGRAM_1_2  COUNT_NGRAM_1_3  \
# Train Accuracy                    0.97             0.97             0.97
# Train F1                          0.74             0.74             0.74
# Train Precision                   0.83             0.83             0.83
# Train Recall                      0.66             0.66             0.66
# Validation Accuracy               0.96             0.96             0.96
# Validation F1                     0.60             0.60             0.60
# Validation Precision              0.86             0.86             0.86
# Validation Recall                 0.46             0.46             0.46
#
#                       TFIDF_VECTORIZER  TFIDF_NGRAM_1_2  TFIDF_NGRAM_1_3
# Train Accuracy                    0.94             0.94             0.94
# Train F1                          0.24             0.20             0.21
# Train Precision                   1.00             1.00             1.00
# Train Recall                      0.14             0.11             0.11
# Validation Accuracy               0.94             0.94             0.94
# Validation F1                     0.20             0.17             0.18
# Validation Precision              1.00             1.00             1.00
# Validation Recall                 0.11             0.09             0.10

# %%
nb_results1.to_csv('data/NB_results.csv', mode = 'a', header ='column_names')

# %%
#MNB with upsampling correction for class imbalance
nb_results3 = wrapper_compare_vectorizations(X_train.lem_tweet, y_train, 
                                   X_val.lem_tweet, y_val, MultinomialNB(), 
                                    vectorization_list, sampling = 'upsample')
nb_results3
# Out:
#                       COUNT_VECTORIZER  COUNT_NGRAM_1_2  COUNT_NGRAM_1_3  \
# Train Accuracy                    0.97             0.97             0.97
# Train F1                          0.97             0.97             0.97
# Train Precision                   0.96             0.96             0.96
# Train Recall                      0.99             0.99             0.99
# Validation Accuracy               0.92             0.92             0.92
# Validation F1                     0.57             0.57             0.57
# Validation Precision              0.45             0.45             0.45
# Validation Recall                 0.79             0.79             0.79
#
#                       TFIDF_VECTORIZER  TFIDF_NGRAM_1_2  TFIDF_NGRAM_1_3
# Train Accuracy                    0.97             0.99             0.99
# Train F1                          0.97             0.99             0.99
# Train Precision                   0.95             0.98             0.99
# Train Recall                      0.99             1.00             1.00
# Validation Accuracy               0.90             0.90             0.90
# Validation F1                     0.53             0.55             0.53
# Validation Precision              0.40             0.41             0.39
# Validation Recall                 0.81             0.82             0.84

# %%
nb_results3.to_csv('data/NB_results.csv', mode = 'a', header ='column_names')

# %%
#MNB with downsampling correction for class imbalance
nb_results4 = wrapper_compare_vectorizations(X_train.lem_tweet, y_train, 
                                   X_val.lem_tweet, y_val, MultinomialNB(), 
                                    vectorization_list, sampling = 'downsample')
nb_results4
# Out:
#                       COUNT_VECTORIZER  COUNT_NGRAM_1_2  COUNT_NGRAM_1_3  \
# Train Accuracy                    0.97             0.97             0.97
# Train F1                          0.97             0.97             0.97
# Train Precision                   0.97             0.97             0.97
# Train Recall                      0.98             0.98             0.98
# Validation Accuracy               0.84             0.84             0.84
# Validation F1                     0.44             0.44             0.44
# Validation Precision              0.29             0.29             0.29
# Validation Recall                 0.89             0.89             0.89
#
#                       TFIDF_VECTORIZER  TFIDF_NGRAM_1_2  TFIDF_NGRAM_1_3
# Train Accuracy                    0.97             0.99             1.00
# Train F1                          0.97             0.99             1.00
# Train Precision                   0.96             1.00             1.00
# Train Recall                      0.98             0.99             1.00
# Validation Accuracy               0.83             0.83             0.83
# Validation F1                     0.43             0.42             0.42
# Validation Precision              0.28             0.27             0.27
# Validation Recall                 0.89             0.87             0.90

# %%
nb_results4.to_csv('data/NB_results.csv', mode = 'a', header ='column_names')

# %%
#MNB with smote correction for class imbalance
nb_results5 = wrapper_compare_vectorizations(X_train.lem_tweet, y_train, 
                                   X_val.lem_tweet, y_val, MultinomialNB(), 
                                    vectorization_list, sampling = 'smote')
nb_results5
# Out:
#                       COUNT_VECTORIZER  COUNT_NGRAM_1_2  COUNT_NGRAM_1_3  \
# Train Accuracy                    0.96             0.96             0.96
# Train F1                          0.76             0.76             0.76
# Train Precision                   0.68             0.68             0.68
# Train Recall                      0.85             0.85             0.85
# Validation Accuracy               0.95             0.95             0.95
# Validation F1                     0.64             0.64             0.64
# Validation Precision              0.60             0.60             0.60
# Validation Recall                 0.67             0.67             0.67
#
#                       TFIDF_VECTORIZER  TFIDF_NGRAM_1_2  TFIDF_NGRAM_1_3
# Train Accuracy                    0.95             0.98             0.99
# Train F1                          0.73             0.86             0.91
# Train Precision                   0.58             0.75             0.84
# Train Recall                      0.99             1.00             1.00
# Validation Accuracy               0.91             0.91             0.91
# Validation F1                     0.56             0.56             0.56
# Validation Precision              0.42             0.43             0.42
# Validation Recall                 0.82             0.83             0.83

# %%
nb_results5.to_csv('data/NB_results.csv', mode = 'a', header ='column_names')

# %% [markdown]
# ### Fine Tuning Based on Best Performance with Count Vectorizer and SMOTE

# %%
np.random.seed(10)

nb = MultinomialNB()

scores = ['accuracy','recall','precision','f1']

nb_gs = GridSearchCV(logreg, param_grid = parameters, 
                           verbose = 0, scoring = scores, cv = 3, refit = 'f1')

# %%
nb_model, nb_X_val, nb_y_train_pred, nb_y_val_pred, \
                nb_y_val_prob, nb_metrics_dict, nb_pred_df = \
wrapper_single_vectorization(X_train.lem_tweet, y_train, X_val.lem_tweet, 
                y_val, nb, count_vect, sampling= 'smote')

# %%
nb_metrics_dict

# %%
seaborn_confusion_matrix(y_val, nb_y_val_pred)

# %%
skplt.metrics.plot_precision_recall_curve(y_val, nb_y_val_prob)

# %%
nb_adj_y_val, cm = adjust_threshold_and_score(y_val, nb_y_val_prob, .2)

# %% [markdown]
# ## Final Naive Bayes Model:  Performance on Test Set

# %%
#use smote and count vectorizer based on validation process
nb_test_model, nb_X_val, nb_y_train_pred, nb_y_val_pred, \
                nb_y_val_prob, nb_metrics_dict, nb_pred_df = \
wrapper_single_vectorization(X_train.lem_tweet, y_train, X_val.lem_tweet, 
                y_val, MultinomialNB(), count_vect, sampling= 'smote')

# %%
#final score based on adjusted threshold
nb_adj_y_true, cm = adjust_threshold_and_score(y_val, nb_y_val_prob, .2)

# %% [markdown]
# # Logistic Regression

# %% [markdown]
# ### Comparing multiple vectorization methods and sampling methods

# %%
#Logistic Regression: lemmatizing + no adjustments
lr_results1 = wrapper_compare_vectorizations(X_train.lem_tweet, 
                            y_train, X_val.lem_tweet, y_val, 
                            LogisticRegression(solver = 'lbfgs', random_state = 10), 
                                            vectorization_list)

lr_results1
# Out:
#                       COUNT_VECTORIZER  COUNT_NGRAM_1_2  COUNT_NGRAM_1_3  \
# Train Accuracy                    0.99             0.99             0.99
# Train F1                          0.89             0.89             0.89
# Train Precision                   0.99             0.99             0.99
# Train Recall                      0.80             0.80             0.80
# Validation Accuracy               0.96             0.96             0.96
# Validation F1                     0.64             0.64             0.64
# Validation Precision              0.85             0.85             0.85
# Validation Recall                 0.51             0.51             0.51
#
#                       TFIDF_VECTORIZER  TFIDF_NGRAM_1_2  TFIDF_NGRAM_1_3
# Train Accuracy                    0.95             0.94             0.94
# Train F1                          0.43             0.29             0.22
# Train Precision                   0.97             0.99             0.99
# Train Recall                      0.28             0.17             0.12
# Validation Accuracy               0.95             0.94             0.94
# Validation F1                     0.44             0.33             0.28
# Validation Precision              0.92             0.91             0.88
# Validation Recall                 0.29             0.20             0.16

# %%
lr_results1.to_csv('data/LR_results.csv',mode = 'a',header ='column_names')

# %%
#Logistic Regression: compare vectorizers using lemmitizing + class balances
lr_results2 = wrapper_compare_vectorizations(X_train.lem_tweet, 
                            y_train, X_val.lem_tweet, y_val, 
                            LogisticRegression(class_weight= 'balanced', 
                            solver = 'lbfgs', random_state = 10), vectorization_list)
lr_results2
# Out:
#                       COUNT_VECTORIZER  COUNT_NGRAM_1_2  COUNT_NGRAM_1_3  \
# Train Accuracy                    0.99             0.99             0.99
# Train F1                          0.93             0.93             0.93
# Train Precision                   0.87             0.87             0.87
# Train Recall                      0.99             0.99             0.99
# Validation Accuracy               0.95             0.95             0.95
# Validation F1                     0.66             0.66             0.66
# Validation Precision              0.62             0.62             0.62
# Validation Recall                 0.72             0.72             0.72
#
#                       TFIDF_VECTORIZER  TFIDF_NGRAM_1_2  TFIDF_NGRAM_1_3
# Train Accuracy                    0.97             0.99             0.99
# Train F1                          0.81             0.91             0.96
# Train Precision                   0.68             0.84             0.92
# Train Recall                      0.99             1.00             1.00
# Validation Accuracy               0.94             0.94             0.94
# Validation F1                     0.63             0.63             0.62
# Validation Precision              0.53             0.55             0.54
# Validation Recall                 0.78             0.74             0.73

# %%
lr_results2.to_csv('data/LR_results.csv',mode = 'a',header ='column_names')

# %%
#Logistic Regression: compare vectorizers using lemmitizing + upsampling
lr_results3 = wrapper_compare_vectorizations(X_train.lem_tweet, 
                            y_train, X_val.lem_tweet, y_val, 
                            LogisticRegression(solver = 'lbfgs', 
                            random_state = 10), vectorization_list, sampling = 'upsample')
lr_results3
# Out:
#                       COUNT_VECTORIZER  COUNT_NGRAM_1_2  COUNT_NGRAM_1_3  \
# Train Accuracy                    0.99             0.99             0.99
# Train F1                          0.99             0.99             0.99
# Train Precision                   0.99             0.99             0.99
# Train Recall                      1.00             1.00             1.00
# Validation Accuracy               0.95             0.95             0.95
# Validation F1                     0.67             0.67             0.67
# Validation Precision              0.63             0.63             0.63
# Validation Recall                 0.70             0.70             0.70
#
#                       TFIDF_VECTORIZER  TFIDF_NGRAM_1_2  TFIDF_NGRAM_1_3
# Train Accuracy                    0.99             1.00             1.00
# Train F1                          0.99             1.00             1.00
# Train Precision                   0.97             0.99             1.00
# Train Recall                      1.00             1.00             1.00
# Validation Accuracy               0.94             0.94             0.93
# Validation F1                     0.62             0.62             0.60
# Validation Precision              0.53             0.54             0.50
# Validation Recall                 0.75             0.74             0.74

# %%
lr_results3.to_csv('data/LR_results.csv',mode = 'a',header ='column_names')

# %%
#Logistic Regression: compare vectorizers using lemmitizing + downsampling
lr_results4 = wrapper_compare_vectorizations(X_train.lem_tweet, 
                            y_train, X_val.lem_tweet, y_val, 
                            LogisticRegression(random_state = 10, solver = 'lbfgs'), 
                            vectorization_list, sampling = 'downsample')
lr_results4
# Out:
#                       COUNT_VECTORIZER  COUNT_NGRAM_1_2  COUNT_NGRAM_1_3  \
# Train Accuracy                    0.99             0.99             0.99
# Train F1                          0.99             0.99             0.99
# Train Precision                   1.00             1.00             1.00
# Train Recall                      0.99             0.99             0.99
# Validation Accuracy               0.85             0.85             0.85
# Validation F1                     0.44             0.44             0.44
# Validation Precision              0.30             0.30             0.30
# Validation Recall                 0.84             0.84             0.84
#
#                       TFIDF_VECTORIZER  TFIDF_NGRAM_1_2  TFIDF_NGRAM_1_3
# Train Accuracy                    0.96             0.98             0.99
# Train F1                          0.96             0.98             0.99
# Train Precision                   0.96             0.98             0.99
# Train Recall                      0.97             0.98             0.99
# Validation Accuracy               0.83             0.81             0.80
# Validation F1                     0.42             0.40             0.38
# Validation Precision              0.27             0.26             0.24
# Validation Recall                 0.86             0.88             0.87

# %%
lr_results4.to_csv('data/LR_results.csv',mode = 'a',header ='column_names')

# %%
#Logistic Regression: compare vectorizers using lemmitizing + smote
lr_results5 = wrapper_compare_vectorizations(X_train.lem_tweet, 
                            y_train, X_val.lem_tweet, y_val, 
                            LogisticRegression(random_state = 10, solver = 'lbfgs'), 
                            vectorization_list, sampling = 'smote', sample_class = 'not majority')
lr_results5
# Out:
#                       COUNT_VECTORIZER  COUNT_NGRAM_1_2  COUNT_NGRAM_1_3  \
# Train Accuracy                    0.96             0.96             0.96
# Train F1                          0.75             0.75             0.75
# Train Precision                   0.66             0.66             0.66
# Train Recall                      0.87             0.87             0.87
# Validation Accuracy               0.89             0.89             0.89
# Validation F1                     0.48             0.48             0.48
# Validation Precision              0.36             0.36             0.36
# Validation Recall                 0.70             0.70             0.70
#
#                       TFIDF_VECTORIZER  TFIDF_NGRAM_1_2  TFIDF_NGRAM_1_3
# Train Accuracy                    0.98             0.99             1.00
# Train F1                          0.85             0.95             0.97
# Train Precision                   0.75             0.91             0.95
# Train Recall                      0.98             0.99             1.00
# Validation Accuracy               0.94             0.95             0.94
# Validation F1                     0.65             0.65             0.65
# Validation Precision              0.56             0.60             0.58
# Validation Recall                 0.75             0.72             0.72

# %%
lr_results5.to_csv('data/LR_results.csv',mode = 'a',header ='column_names')

# %% [markdown]
# ## Grid Searching 2:

# %%
from imblearn.over_sampling import RandomOverSampler

# %%
count_vect = CountVectorizer()

# %%
Xt = count_vect.fit_transform(X_train.lem_tweet)

# %%
Xvt = count_vect.transform(X_val.lem_tweet)

# %%
ros = RandomOverSampler(random_state=10, sampling_strategy = 'minority')

# %%
X_up, y_up = upsample_training_data(Xt, y_train)

# %%
X_up, y_up
# Out:
# (                                                       0
#  6150     (0, 3623)\t1\n  (0, 1341)\t1\n  (0, 13321)\t...
#  2964     (0, 22876)\t1\n  (0, 28229)\t1\n  (0, 9635)\...
#  12469    (0, 9614)\t1\n  (0, 22358)\t1\n  (0, 7856)\t...
#  7697     (0, 24571)\t1\n  (0, 9292)\t1\n  (0, 5536)\t...
#  8774     (0, 23271)\t1\n  (0, 22943)\t1\n  (0, 22669)...
#  2913                       (0, 1602)\t1\n  (0, 16694)\t1
#  3696     (0, 22277)\t1\n  (0, 22773)\t1\n  (0, 4119)\...
#  16963    (0, 12135)\t1\n  (0, 3125)\t1\n  (0, 28064)\...
#  11665    (0, 25525)\t1\n  (0, 4544)\t1\n  (0, 8181)\t...
#  20195      (0, 4288)\t1\n  (0, 5017)\t1\n  (0, 12933)\t1
#  160      (0, 11907)\t1\n  (0, 16389)\t1\n  (0, 16386)...
#  1561     (0, 24973)\t1\n  (0, 24975)\t1\n  (0, 11852)...
#  6031     (0, 24932)\t1\n  (0, 17200)\t1\n  (0, 18472)...
#  11555    (0, 23107)\t1\n  (0, 15861)\t1\n  (0, 12442)...
#  911      (0, 11886)\t1\n  (0, 173)\t1\n  (0, 19325)\t...
#  11808    (0, 18992)\t1\n  (0, 22636)\t1\n  (0, 17124)...
#  9977     (0, 10028)\t1\n  (0, 4822)\t1\n  (0, 25743)\...
#  8790     (0, 20854)\t1\n  (0, 27887)\t1\n  (0, 22607)...
#  12489    (0, 17732)\t1\n  (0, 15039)\t1\n  (0, 13863)...
#  8451     (0, 9666)\t1\n  (0, 20075)\t1\n  (0, 1210)\t...
#  5661     (0, 14824)\t1\n  (0, 20689)\t1\n  (0, 16386)...
#  9395     (0, 21376)\t1\n  (0, 25008)\t1\n  (0, 22556)...
#  1225     (0, 20590)\t1\n  (0, 24153)\t1\n  (0, 14537)...
#  8155     (0, 12357)\t1\n  (0, 14017)\t1\n  (0, 27258)...
#  8643     (0, 20870)\t1\n  (0, 15497)\t1\n  (0, 24678)...
#  2905     (0, 19078)\t1\n  (0, 9045)\t1\n  (0, 28067)\...
#  13598    (0, 93)\t1\n  (0, 22013)\t1\n  (0, 6237)\t1\...
#  12905    (0, 16229)\t1\n  (0, 27343)\t1\n  (0, 3768)\...
#  4835     (0, 6854)\t1\n  (0, 826)\t1\n  (0, 20646)\t1...
#  19965    (0, 19095)\t1\n  (0, 13406)\t2\n  (0, 2827)\...
#  ...                                                  ...
#  20409    (0, 13234)\t1\n  (0, 3257)\t1\n  (0, 2869)\t...
#  20410    (0, 17315)\t1\n  (0, 10932)\t2\n  (0, 14854)...
#  20411    (0, 12183)\t1\n  (0, 6600)\t1\n  (0, 28088)\...
#  20412    (0, 26645)\t1\n  (0, 16339)\t1\n  (0, 24730)...
#  20413    (0, 9948)\t1\n  (0, 9947)\t2\n  (0, 11688)\t...
#  20414    (0, 6263)\t1\n  (0, 10418)\t1\n  (0, 28384)\...
#  20415    (0, 23679)\t1\n  (0, 8695)\t1\n  (0, 4850)\t...
#  20416    (0, 14717)\t1\n  (0, 26785)\t1\n  (0, 5049)\...
#  20419    (0, 2058)\t1\n  (0, 25238)\t1\n  (0, 5453)\t...
#  20421    (0, 15016)\t1\n  (0, 10662)\t1\n  (0, 23406)...
#  20422       (0, 12286)\t1\n  (0, 6651)\t1\n  (0, 889)\t1
#  20423    (0, 18380)\t1\n  (0, 28384)\t1\n  (0, 22050)...
#  20424    (0, 12078)\t1\n  (0, 11430)\t2\n  (0, 15817)...
#  20425    (0, 11500)\t1\n  (0, 9560)\t1\n  (0, 23960)\...
#  20428    (0, 3082)\t1\n  (0, 21745)\t1\n  (0, 16277)\...
#  20431    (0, 27432)\t1\n  (0, 10077)\t1\n  (0, 23326)...
#  20432    (0, 17036)\t1\n  (0, 18062)\t1\n  (0, 7089)\...
#  20435    (0, 21129)\t1\n  (0, 14468)\t1\n  (0, 5035)\...
#  20436    (0, 18299)\t1\n  (0, 6587)\t1\n  (0, 5813)\t...
#  20438    (0, 6627)\t1\n  (0, 21129)\t1\n  (0, 8319)\t...
#  20439    (0, 14533)\t1\n  (0, 28434)\t1\n  (0, 6940)\...
#  20440    (0, 23350)\t1\n  (0, 27475)\t1\n  (0, 8168)\...
#  20441    (0, 25172)\t1\n  (0, 20351)\t1\n  (0, 3125)\...
#  20442    (0, 2895)\t1\n  (0, 25059)\t1\n  (0, 6358)\t...
#  20445    (0, 2320)\t1\n  (0, 13972)\t1\n  (0, 23406)\...
#  20446    (0, 4380)\t1\n  (0, 3991)\t1\n  (0, 25758)\t...
#  20449    (0, 4742)\t1\n  (0, 21241)\t1\n  (0, 3883)\t...
#  20450    (0, 7929)\t1\n  (0, 25039)\t1\n  (0, 11100)\...
#  20453    (0, 327)\t1\n  (0, 11291)\t1\n  (0, 23875)\t...
#  20454    (0, 16235)\t1\n  (0, 22181)\t1\n  (0, 4860)\...
#
#  [24438 rows x 1 columns], 6150     1.0
#  2964     1.0
#  12469    1.0
#  7697     1.0
#  8774     1.0
#  2913     1.0
#  3696     1.0
#  16963    1.0
#  11665    1.0
#  20195    1.0
#  160      1.0
#  1561     1.0
#  6031     1.0
#  11555    1.0
#  911      1.0
#  11808    1.0
#  9977     1.0
#  8790     1.0
#  12489    1.0
#  8451     1.0
#  5661     1.0
#  9395     1.0
#  1225     1.0
#  8155     1.0
#  8643     1.0
#  2905     1.0
#  13598    1.0
#  12905    1.0
#  4835     1.0
#  19965    1.0
#          ...
#  20409    0.0
#  20410    0.0
#  20411    0.0
#  20412    0.0
#  20413    0.0
#  20414    0.0
#  20415    0.0
#  20416    0.0
#  20419    0.0
#  20421    0.0
#  20422    0.0
#  20423    0.0
#  20424    0.0
#  20425    0.0
#  20428    0.0
#  20431    0.0
#  20432    0.0
#  20435    0.0
#  20436    0.0
#  20438    0.0
#  20439    0.0
#  20440    0.0
#  20441    0.0
#  20442    0.0
#  20445    0.0
#  20446    0.0
#  20449    0.0
#  20450    0.0
#  20453    0.0
#  20454    0.0
#  Name: label, Length: 24438, dtype: float64)

# %%
results_lr2 = logreg.fit(X_up, y_up)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-41-0fa550de73a4> in <module>
# ----> 1 results_lr2 = logreg.fit(X_up, y_up)
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py in fit(self, X, y, sample_weight)
#    1530
#    1531         X, y = check_X_y(X, y, accept_sparse='csr', dtype=_dtype, order="C",
# -> 1532                          accept_large_sparse=solver != 'liblinear')
#    1533         check_classification_targets(y)
#    1534         self.classes_ = np.unique(y)
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
#     717                     ensure_min_features=ensure_min_features,
#     718                     warn_on_dtype=warn_on_dtype,
# --> 719                     estimator=estimator)
#     720     if multi_output:
#     721         y = check_array(y, 'csr', force_all_finite=True, ensure_2d=False,
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     494             try:
#     495                 warnings.simplefilter('error', ComplexWarning)
# --> 496                 array = np.asarray(array, dtype=dtype, order=order)
#     497             except ComplexWarning:
#     498                 raise ValueError("Complex data not supported\n"
#
# ~/anaconda3/lib/python3.7/site-packages/numpy/core/numeric.py in asarray(a, dtype, order)
#     536
#     537     """
# --> 538     return array(a, dtype, copy=False, order=order)
#     539
#     540
#
# ValueError: setting an array element with a sequence.

# %%
lr_gs_model1, lr_X_val1, lr_y_train_pred1, lr_y_val_pred1, \
                lr_y_val_prob1, lr_metrics_dict1, lr_pred_df1 = \
upsample_vector_model(X_train.lem_tweet, y_train, X_val.lem_tweet, 
                y_val, LogisticRegression (random_state=10), count_vect)

# %%
lr_metrics_dict1

# %%
X_ros, y_ros = ros.fit_resample(Xt, y_train)

# %%
results_lr = logreg.fit (X_ros,y_ros)

# %%
y_ros_pred = logreg.predict(X_ros)

# %%
X_ros.shape

# %%
y_ros.shape

# %%
logreg.score (X_ros,y_ros)
# Out:
# 0.9947423764458465

# %%
Xt.shape
# Out:
# (20455, 28654)

# %%
metrics.precision_score(y_ros, y_ros_pred)
# Out:
# 0.9932382849355278

# %%
metrics.accuracy_score(y_ros, y_ros_pred)
# Out:
# 0.9947423764458465

# %%
metrics.f1_score(y_ros, y_ros_pred)
# Out:
# 0.9947503805974066

# %%
Xt.shape

# %%
Xvt.shape

# %%
yvt = logreg.predict(Xvt)

# %%
metrics.f1_score(yvt, y_val)
# Out:
# 0.6666666666666666

# %%
# c_space = np.linspace (.1, 10, 100)

count_vect = CountVectorizer()
TfidfVectorizer

parameters = { 'logisticregression__C': [.001, .1, .5, 1, 5, 8, 10],
              'logisticregression__penalty': ['l1', 'l2']}

lr = LogisticRegression(random_state = 10)
pipe = make_pipeline(count_vect, ros, lr)

scores = ['accuracy','precision','recall','f1']

grid = GridSearchCV(pipe, param_grid = parameters, 
                           verbose = 0, scoring = scores, cv = 3, refit = 'f1', return_train_score=True)
    
grid.fit(X_train.lem_tweet, y_train)
# Out:
# GridSearchCV(cv=3, error_score='raise-deprecating',
#              estimator=Pipeline(memory=None,
#                                 steps=[('countvectorizer',
#                                         CountVectorizer(analyzer='word',
#                                                         binary=False,
#                                                         decode_error='strict',
#                                                         dtype=<class 'numpy.int64'>,
#                                                         encoding='utf-8',
#                                                         input='content',
#                                                         lowercase=True,
#                                                         max_df=1.0,
#                                                         max_features=None,
#                                                         min_df=1,
#                                                         ngram_range=(1, 1),
#                                                         preprocessor=None,
#                                                         stop_words=None,
#                                                         strip_accen...
#                                                            n_jobs=None,
#                                                            penalty='l2',
#                                                            random_state=10,
#                                                            solver='warn',
#                                                            tol=0.0001,
#                                                            verbose=0,
#                                                            warm_start=False))],
#                                 verbose=False),
#              iid='warn', n_jobs=None,
#              param_grid={'logisticregression__C': [0.001, 0.1, 0.5, 1, 5, 8,
#                                                    10],
#                          'logisticregression__penalty': ['l1', 'l2']},
#              pre_dispatch='2*n_jobs', refit='f1', return_train_score=True,
#              scoring=['accuracy', 'precision', 'recall', 'f1'], verbose=0)

# %%
grid.best_params_
# Out:
# {'logisticregression__C': 1, 'logisticregression__penalty': 'l2'}

# %%
rosdf = pd.DataFrame(grid.cv_results_)
rosdf.head()
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       0.839176      0.005772         1.273821        0.095428
# 1       0.925792      0.010843         1.154761        0.042401
# 2       1.032348      0.021862         1.301557        0.122417
# 3       1.487220      0.176811         1.150906        0.004143
# 4       1.246218      0.144490         1.239258        0.033646
#
#   param_logisticregression__C param_logisticregression__penalty  \
# 0                       0.001                                l1
# 1                       0.001                                l2
# 2                         0.1                                l1
# 3                         0.1                                l2
# 4                         0.5                                l1
#
#                                               params  split0_test_accuracy  \
# 0  {'logisticregression__C': 0.001, 'logisticregr...              0.929755
# 1  {'logisticregression__C': 0.001, 'logisticregr...              0.801144
# 2  {'logisticregression__C': 0.1, 'logisticregres...              0.902478
# 3  {'logisticregression__C': 0.1, 'logisticregres...              0.935034
# 4  {'logisticregression__C': 0.5, 'logisticregres...              0.942514
#
#    split1_test_accuracy  split2_test_accuracy  ...  split1_test_f1  \
# 0              0.929891              0.929891  ...        0.000000
# 1              0.806395              0.812702  ...        0.342629
# 2              0.895864              0.897624  ...        0.497167
# 3              0.926958              0.931798  ...        0.580808
# 4              0.938252              0.936785  ...        0.601703
#
#    split2_test_f1  mean_test_f1  std_test_f1  rank_test_f1  split0_train_f1  \
# 0        0.000000      0.000000     0.000000            14         0.000000
# 1        0.355376      0.347433     0.005657            13         0.380478
# 2        0.502849      0.507086     0.010274            12         0.584500
# 3        0.582960      0.590924     0.012814            11         0.806382
# 4        0.583575      0.603267     0.016753            10         0.861538
#
#    split1_train_f1  split2_train_f1  mean_train_f1  std_train_f1
# 0         0.000000         0.000000       0.000000      0.000000
# 1         0.381494         0.385736       0.382569      0.002277
# 2         0.612536         0.594278       0.597104      0.011619
# 3         0.815199         0.815232       0.812271      0.004164
# 4         0.867701         0.862069       0.863769      0.002788
#
# [5 rows x 51 columns]

# %%
ros_df = rosdf[['mean_train_f1', 'mean_test_f1']]
ros_df.head(10)
# Out:
#    mean_train_f1  mean_test_f1
# 0       0.000000      0.000000
# 1       0.382569      0.347433
# 2       0.597104      0.507086
# 3       0.812271      0.590924
# 4       0.863769      0.603267
# 5       0.933595      0.625527
# 6       0.933408      0.610001
# 7       0.965390      0.628676
# 8       0.997220      0.611354
# 9       0.994797      0.619020

# %%
grid.best_score_
# Out:
# 0.6286755443709123

# %% [markdown]
# ### Grid Searching for Best Hyperparameters

# %%
np.random.seed(10)

logreg = LogisticRegression(random_state= 10)
c_space = np.linspace (.1, 10, 100)

parameters = {'C': c_space, 
              'penalty': ['l1', 'l2']}

scores = ['accuracy','recall','precision','f1']

lr_gs = GridSearchCV(logreg, param_grid = parameters, 
                           verbose = 0, scoring = scores, cv = 3, refit = 'f1')

# %%
lr_gs_model, lr_X_val, lr_y_train_pred, lr_y_val_pred, \
                lr_y_val_prob, lr_metrics_dict, lr_pred_df = \
wrapper_single_vectorization(X_train.lem_tweet, y_train, X_val.lem_tweet,y_val, 
                             lr_gs, count_vect, sampling= 'upsample')

# %%
lr_gs_model.best_params_
# Out:
# {'C': 8.4, 'penalty': 'l1'}

# %%
lr_metrics_dict
# Out:
# {'Train Accuracy': 1.0,
#  'Train Precision': 1.0,
#  'Train Recall': 1.0,
#  'Train F1': 1.0,
#  'Validation Accuracy': 0.95,
#  'Validation Precision': 0.65,
#  'Validation Recall': 0.66,
#  'Validation F1': 0.65}

# %%
lr_gs_df = pd.DataFrame(lr_gs_model.cv_results_)
lr_gs_df[lr_gs_df.rank_test_f1 == 1]
# Out:
#      mean_fit_time  std_fit_time  mean_score_time  std_score_time param_C  \
# 166       0.545435      0.039122         0.036324        0.006929     8.4
#
#     param_penalty                       params  split0_test_accuracy  \
# 166            l1  {'C': 8.4, 'penalty': 'l1'}              0.984858
#
#      split1_test_accuracy  split2_test_accuracy  ...  split2_test_precision  \
# 166              0.980284              0.983754  ...               0.969247
#
#      mean_test_precision  std_test_precision  rank_test_precision  \
# 166             0.967788            0.004206                   10
#
#      split0_test_f1  split1_test_f1  split2_test_f1  mean_test_f1  \
# 166        0.985061        0.980665        0.984001      0.983242
#
#      std_test_f1  rank_test_f1
# 166     0.001873             1
#
# [1 rows x 31 columns]

# %%
lr_model, lr_X_val, lr_y_train_pred, lr_y_val_pred, \
                lr_y_val_prob, lr_metrics_dict, lr_pred_df = \
wrapper_single_vectorization(X_train.lem_tweet, y_train, X_val.lem_tweet, 
                y_val, LogisticRegression(C = 8.4, penalty = 'l1', random_state = 10),                                          
                 count_vect, sampling= 'upsample')

# %%
lr_metrics_dict
# Out:
# {'Train Accuracy': 1.0,
#  'Train Precision': 1.0,
#  'Train Recall': 1.0,
#  'Train F1': 1.0,
#  'Validation Accuracy': 0.95,
#  'Validation Precision': 0.65,
#  'Validation Recall': 0.66,
#  'Validation F1': 0.65}

# %%
#want to reduce number of records predicted as 0 that are actually 1 
seaborn_confusion_matrix(y_val, lr_y_val_pred)

# %%
skplt.metrics.plot_precision_recall_curve(y_val, lr_y_val_prob)

# %%
lr_pred_adj, cm = adjust_threshold_and_score(y_val, lr_y_val_prob, .2)
# Out:
# Adjusted Accuracy: 0.9587407117716074
# Adjusted Precision: 0.7466666666666667
# Adjusted Recall: 0.6239554317548747
# Adjusted F1 Score: 0.6798179059180577

# %%
lr_pred_df['adjusted class'] = lr_pred_adj

# %%
lr_pred_df.head()

# %%
lr_misclassified_df = lr_pred_df[lr_pred_df['predicted class'] != lr_pred_df['actual class']]
lr_misclassified_df.head()

# %%
lr_misclassified_df.shape

# %%
lr_misclassified2_df = lr_misclassified_df[lr_misclassified_df['adjusted class'] != lr_misclassified_df['actual class']]
lr_misclassified2_df.head()

# %%
lr_misclassified2_df.shape

# %%
df.tweet[12608]

# %%
df.lem_tweet[28669]

# %%
df.tweet[2748]

# %%
# import eli5
# from eli5 import explain_weights, explain_prediction
# from eli5.formatters import format_as_html, format_as_text, format_html_styles, fields

# %%
# eli5.show_weights(log, vec= count_vect, target_names= y_test, horizontal_layout=False)

# %%
# skplt.metrics.plot_precision_recall_curve(y_test, lr_y_prob_test)

# %% [markdown]
# ## SVM

# %%
#SVM with lemmatizing + no class balance corrections
svm_results1 = wrapper_compare_vectorizations(X_train.lem_tweet, 
                            y_train, X_val.lem_tweet, y_val, 
                            SVC(gamma='auto', probability = True, random_state = 10), 
                            vectorization_list)
svm_results1
# Out:
#                       COUNT_VECTORIZER  COUNT_NGRAM_1_2  COUNT_NGRAM_1_3  \
# Train Accuracy                    0.93             0.93             0.93
# Train F1                          0.00             0.00             0.00
# Train Precision                   0.00             0.00             0.00
# Train Recall                      0.00             0.00             0.00
# Validation Accuracy               0.93             0.93             0.93
# Validation F1                     0.00             0.00             0.00
# Validation Precision              0.00             0.00             0.00
# Validation Recall                 0.00             0.00             0.00
#
#                       TFIDF_VECTORIZER  TFIDF_NGRAM_1_2  TFIDF_NGRAM_1_3
# Train Accuracy                    0.93             0.93             0.93
# Train F1                          0.00             0.00             0.00
# Train Precision                   0.00             0.00             0.00
# Train Recall                      0.00             0.00             0.00
# Validation Accuracy               0.93             0.93             0.93
# Validation F1                     0.00             0.00             0.00
# Validation Precision              0.00             0.00             0.00
# Validation Recall                 0.00             0.00             0.00

# %%
# svm_results1.to_csv('data/SVM_results.csv',mode = 'a',header ='column_names')

# %%
#SVM with lemmatizing + class weight 'balanced' correction
svm_results2 = wrapper_compare_vectorizations(X_train.lem_tweet, 
                            y_train, X_val.lem_tweet, y_val, 
                            SVC(gamma='auto', class_weight = 'balanced', probability = True, random_state = 10), 
                            vectorization_list)
svm_results2
# Out:
#                       COUNT_VECTORIZER  COUNT_NGRAM_1_2  COUNT_NGRAM_1_3  \
# Train Accuracy                    0.07             0.07             0.07
# Train F1                          0.13             0.13             0.13
# Train Precision                   0.07             0.07             0.07
# Train Recall                      1.00             1.00             1.00
# Validation Accuracy               0.07             0.07             0.07
# Validation F1                     0.13             0.13             0.13
# Validation Precision              0.07             0.07             0.07
# Validation Recall                 1.00             1.00             1.00
#
#                       TFIDF_VECTORIZER  TFIDF_NGRAM_1_2  TFIDF_NGRAM_1_3
# Train Accuracy                    0.07             0.07             0.07
# Train F1                          0.13             0.13             0.13
# Train Precision                   0.07             0.07             0.07
# Train Recall                      1.00             1.00             1.00
# Validation Accuracy               0.07             0.07             0.07
# Validation F1                     0.13             0.13             0.13
# Validation Precision              0.07             0.07             0.07
# Validation Recall                 1.00             1.00             1.00

# %%
# svm_results2.to_csv('data/SVM_results.csv', mode = 'a',header ='column_names')

# %%
svm_results3 = wrapper_compare_vectorizations(X_train.lem_tweet, 
                            y_train, X_val.lem_tweet, y_val, 
                            SVC(gamma='auto', probability = True, random_state = 10), 
                            vectorization_list, sampling = 'upsample')
svm_results3
# Out:
#                       COUNT_VECTORIZER  COUNT_NGRAM_1_2  COUNT_NGRAM_1_3  \
# Train Accuracy                    0.66             0.66             0.66
# Train F1                          0.74             0.74             0.74
# Train Precision                   0.60             0.60             0.60
# Train Recall                      0.97             0.97             0.97
# Validation Accuracy               0.39             0.39             0.39
# Validation F1                     0.18             0.18             0.18
# Validation Precision              0.10             0.10             0.10
# Validation Recall                 0.97             0.97             0.97
#
#                       TFIDF_VECTORIZER  TFIDF_NGRAM_1_2  TFIDF_NGRAM_1_3
# Train Accuracy                    0.62             0.53             0.53
# Train F1                          0.40             0.13             0.13
# Train Precision                   0.98             1.00             1.00
# Train Recall                      0.25             0.07             0.07
# Validation Accuracy               0.94             0.93             0.93
# Validation F1                     0.35             0.11             0.11
# Validation Precision              0.59             1.00             1.00
# Validation Recall                 0.25             0.06             0.06

# %%
# SVM with lemmatizing + downsampling
svm_results4 = wrapper_compare_vectorizations(X_train.lem_tweet, 
                            y_train, X_val.lem_tweet, y_val, 
                            SVC(gamma= 'auto', probability = True, random_state = 10), 
                            vectorization_list, sampling = 'downsample')
svm_results4
# Out:
#                       COUNT_VECTORIZER  COUNT_NGRAM_1_2  COUNT_NGRAM_1_3  \
# Train Accuracy                    0.51             0.51             0.51
# Train F1                          0.67             0.67             0.67
# Train Precision                   0.51             0.51             0.51
# Train Recall                      1.00             1.00             1.00
# Validation Accuracy               0.10             0.10             0.10
# Validation F1                     0.13             0.13             0.13
# Validation Precision              0.07             0.07             0.07
# Validation Recall                 1.00             1.00             1.00
#
#                       TFIDF_VECTORIZER  TFIDF_NGRAM_1_2  TFIDF_NGRAM_1_3
# Train Accuracy                    0.66             0.54             0.54
# Train F1                          0.50             0.16             0.16
# Train Precision                   0.97             1.00             1.00
# Train Recall                      0.34             0.09             0.09
# Validation Accuracy               0.93             0.94             0.94
# Validation F1                     0.43             0.14             0.14
# Validation Precision              0.48             1.00             1.00
# Validation Recall                 0.38             0.08             0.08

# %%
svm_results5 = wrapper_compare_vectorizations(X_train.lem_tweet, 
                            y_train, X_val.lem_tweet, y_val, 
                            SVC(gamma='auto', probability = True, random_state = 10), 
                            vectorization_list, sampling = 'smote')
svm_results5
# Out:
#                       COUNT_VECTORIZER  COUNT_NGRAM_1_2  COUNT_NGRAM_1_3  \
# Train Accuracy                    0.18             0.18             0.18
# Train F1                          0.14             0.14             0.14
# Train Precision                   0.07             0.07             0.07
# Train Recall                      0.92             0.92             0.92
# Validation Accuracy               0.19             0.19             0.19
# Validation F1                     0.14             0.14             0.14
# Validation Precision              0.08             0.08             0.08
# Validation Recall                 0.93             0.93             0.93
#
#                       TFIDF_VECTORIZER  TFIDF_NGRAM_1_2  TFIDF_NGRAM_1_3
# Train Accuracy                    0.94             0.94             0.94
# Train F1                          0.47             0.17             0.14
# Train Precision                   0.67             0.99             1.00
# Train Recall                      0.37             0.09             0.08
# Validation Accuracy               0.94             0.94             0.93
# Validation F1                     0.47             0.15             0.13
# Validation Precision              0.58             1.00             1.00
# Validation Recall                 0.40             0.08             0.07

# %% [markdown]
# #### Randomized Search to optimize SVM Hyperparameters:

# %%
svc = SVC (random_state= 10)

params = {
'C': [0.1,.2, .5, 0.8, 1, 1.5, 2.0, 3.0, 4.0, 5.0],
'kernel':['linear', 'rbf'],
'gamma' :[0.1,0.8,1,1.2,1.4]}
scores = ['accuracy','recall','precision','f1']

scv_rs = RandomizedSearchCV(svc, param_distributions = parameters, scoring = scores, cv = 3, refit = 'f1')

# %% [markdown]
# # Random Forest

# %% [markdown]
# ### Comparing Classifier Performance with Multiple Vectorizer Methods and Class Imbalance Corrections

# %%
#Random Forest: compare vectorizers with lemmatizing; no explicit class balance corrections
rfc_results1 = wrapper_compare_vectorizations(X_train.lem_tweet, 
                            y_train, X_val.lem_tweet, y_val, 
                            RandomForestClassifier(random_state=10), vectorization_list)
rfc_results1
# Out:
#                       COUNT_VECTORIZER  COUNT_NGRAM_1_2  COUNT_NGRAM_1_3  \
# Train Accuracy                    0.99             0.99             0.99
# Train F1                          0.95             0.95             0.95
# Train Precision                   1.00             1.00             1.00
# Train Recall                      0.91             0.91             0.91
# Validation Accuracy               0.96             0.96             0.96
# Validation F1                     0.61             0.61             0.61
# Validation Precision              0.93             0.93             0.93
# Validation Recall                 0.45             0.45             0.45
#
#                       TFIDF_VECTORIZER  TFIDF_NGRAM_1_2  TFIDF_NGRAM_1_3
# Train Accuracy                    0.99             0.99             0.99
# Train F1                          0.95             0.93             0.94
# Train Precision                   1.00             1.00             1.00
# Train Recall                      0.91             0.88             0.88
# Validation Accuracy               0.96             0.96             0.96
# Validation F1                     0.62             0.58             0.57
# Validation Precision              0.88             0.95             0.95
# Validation Recall                 0.48             0.42             0.40

# %%
# rfc_results1.to_csv('data/RFC_results.csv',mode = 'a',header ='column_names')

# %%
#Random Forest: compare vectorizers with lemmatizing and class weights balanced
rfc_results2 = wrapper_compare_vectorizations(X_train.lem_tweet, 
                            y_train, X_val.lem_tweet, y_val, 
                            RandomForestClassifier(random_state=10, class_weight = 'balanced'), 
                            vectorization_list)
rfc_results2
# Out:
#                       COUNT_VECTORIZER  COUNT_NGRAM_1_2  COUNT_NGRAM_1_3  \
# Train Accuracy                    0.99             0.99             0.99
# Train F1                          0.95             0.95             0.95
# Train Precision                   1.00             1.00             1.00
# Train Recall                      0.91             0.91             0.91
# Validation Accuracy               0.96             0.96             0.96
# Validation F1                     0.54             0.54             0.54
# Validation Precision              0.98             0.98             0.98
# Validation Recall                 0.37             0.37             0.37
#
#                       TFIDF_VECTORIZER  TFIDF_NGRAM_1_2  TFIDF_NGRAM_1_3
# Train Accuracy                    0.99             0.99             0.99
# Train F1                          0.94             0.94             0.93
# Train Precision                   1.00             1.00             1.00
# Train Recall                      0.89             0.88             0.88
# Validation Accuracy               0.95             0.95             0.95
# Validation F1                     0.51             0.50             0.49
# Validation Precision              0.93             0.95             0.95
# Validation Recall                 0.35             0.34             0.33

# %%
# rfc_results2.to_csv('data/RFC_results.csv',mode = 'a',header ='column_names')

# %%
#Random Forest: compare vectorizers with lemmatizing and upsampling
rfc_results3 = wrapper_compare_vectorizations(X_train.lem_tweet, 
                            y_train, X_val.lem_tweet, y_val, 
                            RandomForestClassifier(random_state=10), 
                            vectorization_list, sampling = 'upsample')
rfc_results3
# Out:
#                       COUNT_VECTORIZER  COUNT_NGRAM_1_2  COUNT_NGRAM_1_3  \
# Train Accuracy                    1.00             1.00             1.00
# Train F1                          1.00             1.00             1.00
# Train Precision                   1.00             1.00             1.00
# Train Recall                      1.00             1.00             1.00
# Validation Accuracy               0.96             0.96             0.96
# Validation F1                     0.59             0.59             0.59
# Validation Precision              0.93             0.93             0.93
# Validation Recall                 0.43             0.43             0.43
#
#                       TFIDF_VECTORIZER  TFIDF_NGRAM_1_2  TFIDF_NGRAM_1_3
# Train Accuracy                    1.00             1.00             1.00
# Train F1                          1.00             1.00             1.00
# Train Precision                   1.00             1.00             1.00
# Train Recall                      1.00             1.00             1.00
# Validation Accuracy               0.96             0.96             0.95
# Validation F1                     0.59             0.56             0.54
# Validation Precision              0.92             0.92             0.89
# Validation Recall                 0.43             0.41             0.39

# %%
# rfc_results3.to_csv('data/RFC_results.csv',mode = 'a',header ='column_names')

# %%
#Random Forest: compare vectorizers with lemmatizing and downsampling
rfc_results4 = wrapper_compare_vectorizations(X_train.lem_tweet, 
                            y_train, X_val.lem_tweet, y_val, 
                            RandomForestClassifier(random_state=10), 
                            vectorization_list, sampling = 'downsample')
rfc_results4
# Out:
#                       COUNT_VECTORIZER  COUNT_NGRAM_1_2  COUNT_NGRAM_1_3  \
# Train Accuracy                    0.99             0.99             0.99
# Train F1                          0.99             0.99             0.99
# Train Precision                   1.00             1.00             1.00
# Train Recall                      0.98             0.98             0.98
# Validation Accuracy               0.86             0.86             0.86
# Validation F1                     0.42             0.42             0.42
# Validation Precision              0.30             0.30             0.30
# Validation Recall                 0.73             0.73             0.73
#
#                       TFIDF_VECTORIZER  TFIDF_NGRAM_1_2  TFIDF_NGRAM_1_3
# Train Accuracy                    0.99             0.99             0.99
# Train F1                          0.99             0.98             0.99
# Train Precision                   1.00             1.00             1.00
# Train Recall                      0.98             0.97             0.98
# Validation Accuracy               0.83             0.85             0.84
# Validation F1                     0.38             0.40             0.38
# Validation Precision              0.26             0.28             0.26
# Validation Recall                 0.77             0.70             0.70

# %%
# rfc_results4.to_csv('data/RFC_results.csv',mode = 'a',header ='column_names')

# %%
#Random Forest: compare vectorizers with lemmatizing and smote
rfc_results5 = wrapper_compare_vectorizations(X_train.lem_tweet, 
                            y_train, X_val.lem_tweet, y_val, 
                            RandomForestClassifier(random_state=10), 
                            vectorization_list, sampling = 'smote', sample_class = 'not majority')
rfc_results5
# Out:
#                       COUNT_VECTORIZER  COUNT_NGRAM_1_2  COUNT_NGRAM_1_3  \
# Train Accuracy                    0.99             0.99             0.99
# Train F1                          0.96             0.96             0.96
# Train Precision                   0.95             0.95             0.95
# Train Recall                      0.96             0.96             0.96
# Validation Accuracy               0.89             0.89             0.89
# Validation F1                     0.42             0.42             0.42
# Validation Precision              0.34             0.34             0.34
# Validation Recall                 0.55             0.55             0.55
#
#                       TFIDF_VECTORIZER  TFIDF_NGRAM_1_2  TFIDF_NGRAM_1_3
# Train Accuracy                    1.00             1.00             1.00
# Train F1                          1.00             0.99             0.99
# Train Precision                   1.00             1.00             1.00
# Train Recall                      0.99             0.99             0.99
# Validation Accuracy               0.95             0.95             0.95
# Validation F1                     0.55             0.53             0.52
# Validation Precision              0.87             0.97             0.92
# Validation Recall                 0.40             0.37             0.36

# %%
# rfc_results5.to_csv('data/RFC_results.csv',mode = 'a',header ='column_names')

# %% [markdown]
# ### Hypertuning Random Forest Hyperparameters: TFIDF Vectorizer and Upsampling

# %%
np.random.seed(0)
rfc = RandomForestClassifier(random_state=10)

parameters = {'n_estimators' : [40, 60, 80, 100, 120],
'max_leaf_nodes' : [100, 200, 300, 400],
'random_state' : [10],
'max_depth': [5, 6, 7, 8, 10, 20, 25, 30],
 'verbose' : [0]}
# 'class_weight': [{0:5, 1:5}, {0:2, 1:8}, {0:4, 1:6}, {0:6, 1: 4}, {0:8, 1:2}]}
#'class_weight': ['balanced', 'balanced_subsample']}

scores = ['accuracy','recall','precision','f1']

rfc_gs = GridSearchCV(rfc, param_grid = parameters, scoring = scores, cv = 3, refit = 'f1')

# %%
rfc_gs_model, rfc_X_val, rfc_y_train_pred, rfc_y_val_pred, \
                rfc_y_val_prob, rfc_metrics_dict, rfc_pred_df = \
wrapper_single_vectorization(X_train.lem_tweet, y_train, X_val.lem_tweet, 
                y_val, rfc_gs, tfidf_vect, sampling = 'upsample')

# %%
rfc_gs_model.best_params_

# %%
rfc_df = pd.DataFrame(rfc_gs_model.cv_results_)
rfc_df.head()

# %%
rfc_df[rfc_df.rank_test_f1==1]

# %%
rfc_gs_model.best_score_

# %%
rfc_metrics_dict

# %%
skplt.metrics.plot_precision_recall_curve(y_val, rfc_y_val_prob)

# %%
rfc_y_val_adj, cm = adjust_threshold_and_score(y_val, rfc_y_val_prob, .46)

# %% [markdown]
# ###  Final Random Forest Model: Test Performance

# %%
rfc = RandomForestClassifier(n_estimators = 60, max_leaf_nodes = 400, 
                       max_depth = 30, random_state = 10, verbose = 0)

# %%
rfc_final_model, rfc_X_test, rfc_y_train2_pred, rfc_y_test2_pred, \
                rfc_y_test2_prob, rfc_metrics2_dict, rfc_pred2_df = \
wrapper_single_vectorization(X_model.lem_tweet, y_model, X_test.lem_tweet, 
                y_test, rfc, count_vect, sampling = 'upsample')

# %%
rfc_metrics_dict

# %%
rfc_adj_y_test, cm = adjust_threshold_and_score(y_test, rfc_y_test_prob, .46)

# %% [markdown]
# # AdaBoost

# %% [markdown]
# ### Comparison Across Multiple Vectorization and Class Imbalance Correction Methods

# %%
#AdaBoost with Decision Tree, lemmatizing + no class balance corrections
ab_results1 = wrapper_compare_vectorizations(X_train.lem_tweet, 
                            y_train, X_val.lem_tweet, y_val, 
                           AdaBoostClassifier(random_state =10), vectorization_list)
ab_results1
# Out:
#                       COUNT_VECTORIZER  COUNT_NGRAM_1_2  COUNT_NGRAM_1_3  \
# Train Accuracy                    0.95             0.95             0.95
# Train F1                          0.47             0.47             0.47
# Train Precision                   0.75             0.75             0.75
# Train Recall                      0.34             0.34             0.34
# Validation Accuracy               0.95             0.95             0.95
# Validation F1                     0.46             0.46             0.46
# Validation Precision              0.77             0.77             0.77
# Validation Recall                 0.33             0.33             0.33
#
#                       TFIDF_VECTORIZER  TFIDF_NGRAM_1_2  TFIDF_NGRAM_1_3
# Train Accuracy                    0.95             0.95             0.95
# Train F1                          0.47             0.46             0.45
# Train Precision                   0.73             0.76             0.77
# Train Recall                      0.35             0.33             0.32
# Validation Accuracy               0.94             0.94             0.94
# Validation F1                     0.47             0.44             0.45
# Validation Precision              0.72             0.74             0.72
# Validation Recall                 0.34             0.32             0.33

# %%
#AdaBoost with Decision Tree, lemmatizing + class balance corrections
dct = DecisionTreeClassifier(class_weight = 'balanced')
ab_results2 = wrapper_compare_vectorizations(X_train.lem_tweet, 
                            y_train, X_val.lem_tweet, y_val, 
                           AdaBoostClassifier(base_estimator = dct, random_state = 10), vectorization_list)
ab_results2
# Out:
#                       COUNT_VECTORIZER  COUNT_NGRAM_1_2  COUNT_NGRAM_1_3  \
# Train Accuracy                    1.00             1.00             1.00
# Train F1                          1.00             1.00             1.00
# Train Precision                   1.00             1.00             1.00
# Train Recall                      1.00             1.00             1.00
# Validation Accuracy               0.92             0.92             0.92
# Validation F1                     0.53             0.53             0.53
# Validation Precision              0.44             0.44             0.44
# Validation Recall                 0.67             0.67             0.67
#
#                       TFIDF_VECTORIZER  TFIDF_NGRAM_1_2  TFIDF_NGRAM_1_3
# Train Accuracy                    1.00             1.00             1.00
# Train F1                          1.00             1.00             1.00
# Train Precision                   1.00             1.00             1.00
# Train Recall                      1.00             1.00             1.00
# Validation Accuracy               0.91             0.92             0.92
# Validation F1                     0.49             0.51             0.50
# Validation Precision              0.41             0.46             0.45
# Validation Recall                 0.60             0.57             0.56

# %%
#AdaBoost with Decision Tree, lemmatizing + upsampling
ab_results3 = wrapper_compare_vectorizations(X_train.lem_tweet, 
                            y_train, X_val.lem_tweet, y_val, 
                           AdaBoostClassifier(random_state =10), vectorization_list, sampling = 'upsample')
ab_results3
# Out:
#                       COUNT_VECTORIZER  COUNT_NGRAM_1_2  COUNT_NGRAM_1_3  \
# Train Accuracy                    0.77             0.77             0.77
# Train F1                          0.74             0.74             0.74
# Train Precision                   0.86             0.86             0.86
# Train Recall                      0.65             0.65             0.65
# Validation Accuracy               0.88             0.88             0.88
# Validation F1                     0.43             0.43             0.43
# Validation Precision              0.32             0.32             0.32
# Validation Recall                 0.65             0.65             0.65
#
#                       TFIDF_VECTORIZER  TFIDF_NGRAM_1_2  TFIDF_NGRAM_1_3
# Train Accuracy                    0.79             0.81             0.81
# Train F1                          0.77             0.80             0.80
# Train Precision                   0.83             0.85             0.85
# Train Recall                      0.72             0.77             0.76
# Validation Accuracy               0.81             0.77             0.73
# Validation F1                     0.35             0.32             0.29
# Validation Precision              0.23             0.20             0.18
# Validation Recall                 0.70             0.79             0.79

# %%
#AdaBoost with Decision Tree, lemmatizing + downsampling
ab_results4 = wrapper_compare_vectorizations(X_train.lem_tweet, 
                            y_train, X_val.lem_tweet, y_val, 
                           AdaBoostClassifier(random_state =10), vectorization_list, sampling = 'downsample')
ab_results4
# Out:
#                       COUNT_VECTORIZER  COUNT_NGRAM_1_2  COUNT_NGRAM_1_3  \
# Train Accuracy                    0.78             0.78             0.78
# Train F1                          0.76             0.76             0.76
# Train Precision                   0.83             0.83             0.83
# Train Recall                      0.70             0.70             0.70
# Validation Accuracy               0.82             0.82             0.82
# Validation F1                     0.35             0.35             0.35
# Validation Precision              0.24             0.24             0.24
# Validation Recall                 0.69             0.69             0.69
#
#                       TFIDF_VECTORIZER  TFIDF_NGRAM_1_2  TFIDF_NGRAM_1_3
# Train Accuracy                    0.79             0.78             0.79
# Train F1                          0.77             0.76             0.76
# Train Precision                   0.86             0.84             0.87
# Train Recall                      0.70             0.70             0.68
# Validation Accuracy               0.82             0.80             0.83
# Validation F1                     0.34             0.32             0.35
# Validation Precision              0.23             0.21             0.24
# Validation Recall                 0.67             0.67             0.65

# %%
#AdaBoost with Decision Tree, lemmatizing + smote
ab_results5 = wrapper_compare_vectorizations(X_train.lem_tweet, 
                            y_train, X_val.lem_tweet, y_val, 
                           AdaBoostClassifier(random_state =10), vectorization_list, sampling = 'smote')
ab_results5
# Out:
#                       COUNT_VECTORIZER  COUNT_NGRAM_1_2  COUNT_NGRAM_1_3  \
# Train Accuracy                    0.73             0.73             0.73
# Train F1                          0.26             0.26             0.26
# Train Precision                   0.16             0.16             0.16
# Train Recall                      0.68             0.68             0.68
# Validation Accuracy               0.72             0.72             0.72
# Validation F1                     0.26             0.26             0.26
# Validation Precision              0.16             0.16             0.16
# Validation Recall                 0.71             0.71             0.71
#
#                       TFIDF_VECTORIZER  TFIDF_NGRAM_1_2  TFIDF_NGRAM_1_3
# Train Accuracy                    0.91             0.90             0.91
# Train F1                          0.45             0.44             0.45
# Train Precision                   0.38             0.38             0.38
# Train Recall                      0.55             0.54             0.55
# Validation Accuracy               0.91             0.90             0.91
# Validation F1                     0.45             0.44             0.45
# Validation Precision              0.39             0.37             0.38
# Validation Recall                 0.54             0.53             0.54

# %% [markdown]
# ### Grid Searching for Best Hyperparameters using....

# %% [markdown]
# ## XGBooster

# %%
xgb_results1 = wrapper_compare_vectorizations(X_train.lem_tweet, 
                            y_train, X_val.lem_tweet, y_val, 
                            XGBClassifier(random_state =10), vectorization_list)
xgb_results1
# Out:
#                       COUNT_VECTORIZER  COUNT_NGRAM_1_2  COUNT_NGRAM_1_3  \
# Train Accuracy                    0.94             0.94             0.94
# Train F1                          0.34             0.34             0.34
# Train Precision                   0.93             0.93             0.93
# Train Recall                      0.21             0.21             0.21
# Validation Accuracy               0.94             0.94             0.94
# Validation F1                     0.34             0.34             0.34
# Validation Precision              0.92             0.92             0.92
# Validation Recall                 0.21             0.21             0.21
#
#                       TFIDF_VECTORIZER  TFIDF_NGRAM_1_2  TFIDF_NGRAM_1_3
# Train Accuracy                    0.94             0.94             0.94
# Train F1                          0.36             0.34             0.35
# Train Precision                   0.94             0.95             0.96
# Train Recall                      0.22             0.21             0.22
# Validation Accuracy               0.94             0.94             0.94
# Validation F1                     0.35             0.34             0.34
# Validation Precision              0.92             0.91             0.93
# Validation Recall                 0.22             0.21             0.21

# %%
#XGB with scale and min child weight set to 1 to correct for class imbalance
xgb_results2 = wrapper_compare_vectorizations(X_train.lem_tweet, 
                            y_train, X_val.lem_tweet, y_val, 
                            XGBClassifier(scale_pos_weight = 1, min_child_weight = 1,
                            random_state =10), vectorization_list)
xgb_results2
# Out:
#                       COUNT_VECTORIZER  COUNT_NGRAM_1_2  COUNT_NGRAM_1_3  \
# Train Accuracy                    0.94             0.94             0.94
# Train F1                          0.34             0.34             0.34
# Train Precision                   0.93             0.93             0.93
# Train Recall                      0.21             0.21             0.21
# Validation Accuracy               0.94             0.94             0.94
# Validation F1                     0.34             0.34             0.34
# Validation Precision              0.92             0.92             0.92
# Validation Recall                 0.21             0.21             0.21
#
#                       TFIDF_VECTORIZER  TFIDF_NGRAM_1_2  TFIDF_NGRAM_1_3
# Train Accuracy                    0.94             0.94             0.94
# Train F1                          0.36             0.34             0.35
# Train Precision                   0.94             0.95             0.96
# Train Recall                      0.22             0.21             0.22
# Validation Accuracy               0.94             0.94             0.94
# Validation F1                     0.35             0.34             0.34
# Validation Precision              0.92             0.91             0.93
# Validation Recall                 0.22             0.21             0.21

# %%
xgb_results3 = wrapper_compare_vectorizations(X_train.lem_tweet, 
                            y_train, X_val.lem_tweet, y_val, 
                            XGBClassifier(random_state =10), vectorization_list, sampling = 'upsample')
xgb_results3
# Out:
#                       COUNT_VECTORIZER  COUNT_NGRAM_1_2  COUNT_NGRAM_1_3  \
# Train Accuracy                    0.81             0.81             0.81
# Train F1                          0.79             0.79             0.79
# Train Precision                   0.87             0.87             0.87
# Train Recall                      0.72             0.72             0.72
# Validation Accuracy               0.87             0.87             0.87
# Validation F1                     0.43             0.43             0.43
# Validation Precision              0.31             0.31             0.31
# Validation Recall                 0.67             0.67             0.67
#
#                       TFIDF_VECTORIZER  TFIDF_NGRAM_1_2  TFIDF_NGRAM_1_3
# Train Accuracy                    0.81             0.83             0.83
# Train F1                          0.79             0.82             0.83
# Train Precision                   0.87             0.87             0.88
# Train Recall                      0.73             0.77             0.78
# Validation Accuracy               0.85             0.78             0.74
# Validation F1                     0.38             0.32             0.30
# Validation Precision              0.27             0.20             0.19
# Validation Recall                 0.67             0.76             0.79

# %%
xgb_results4 = wrapper_compare_vectorizations(X_train.lem_tweet, 
                            y_train, X_val.lem_tweet, y_val, 
                            XGBClassifier(random_state =10), vectorization_list, sampling = 'downsample')
xgb_results4
# Out:
#                       COUNT_VECTORIZER  COUNT_NGRAM_1_2  COUNT_NGRAM_1_3  \
# Train Accuracy                    0.79             0.79             0.79
# Train F1                          0.78             0.78             0.78
# Train Precision                   0.86             0.86             0.86
# Train Recall                      0.71             0.71             0.71
# Validation Accuracy               0.83             0.83             0.83
# Validation F1                     0.37             0.37             0.37
# Validation Precision              0.25             0.25             0.25
# Validation Recall                 0.70             0.70             0.70
#
#                       TFIDF_VECTORIZER  TFIDF_NGRAM_1_2  TFIDF_NGRAM_1_3
# Train Accuracy                    0.80             0.81             0.81
# Train F1                          0.78             0.79             0.80
# Train Precision                   0.87             0.87             0.86
# Train Recall                      0.71             0.72             0.74
# Validation Accuracy               0.82             0.83             0.83
# Validation F1                     0.34             0.36             0.37
# Validation Precision              0.23             0.24             0.25
# Validation Recall                 0.69             0.69             0.70

# %%
xgb_results5 = wrapper_compare_vectorizations(X_train.lem_tweet, 
                            y_train, X_val.lem_tweet, y_val, 
                            XGBClassifier(random_state =10), vectorization_list, sampling = 'smote')
xgb_results5
# Out:
#                       COUNT_VECTORIZER  COUNT_NGRAM_1_2  COUNT_NGRAM_1_3  \
# Train Accuracy                    0.94             0.94             0.94
# Train F1                          0.38             0.38             0.38
# Train Precision                   0.77             0.77             0.77
# Train Recall                      0.25             0.25             0.25
# Validation Accuracy               0.94             0.94             0.94
# Validation F1                     0.35             0.35             0.35
# Validation Precision              0.70             0.70             0.70
# Validation Recall                 0.23             0.23             0.23
#
#                       TFIDF_VECTORIZER  TFIDF_NGRAM_1_2  TFIDF_NGRAM_1_3
# Train Accuracy                    0.94             0.94             0.94
# Train F1                          0.45             0.45             0.44
# Train Precision                   0.62             0.64             0.66
# Train Recall                      0.35             0.34             0.33
# Validation Accuracy               0.94             0.94             0.94
# Validation F1                     0.46             0.45             0.43
# Validation Precision              0.64             0.68             0.71
# Validation Recall                 0.36             0.33             0.31

# %% [markdown]
# # Word to Vec: Training Model and Testing Classifiers

# %% [markdown]
# ### X-train pre-processing

# %%
X_train_token_list = list(X_train.tokenized_tweet)

# %%
X_train_token_sumlist = sum(X_train_token_list,[])
X_train_unique_tokens = set(X_train_token_sumlist)
print('The unique number of words in the training dataset is: {}'.format(len(X_train_unique_tokens)))
# Out:
# The unique number of words in the training dataset is: 28682

# %% [markdown]
# #### X-val pre-processing

# %%
X_val_token_list = list(X_val['tokenized_tweet'])

# %%
X_val_token_sumlist = sum(X_val_token_list,[])
X_val_unique_tokens = set(X_val_token_sumlist)

print('The unique number of words in the validation dataset is: {}'.format(len(X_val_unique_tokens)))
# Out:
# The unique number of words in the validation dataset is: 11761

# %% [markdown]
# #### X-test pre-processing

# %%
X_test_token_list = list(X_test['tokenized_tweet'])

# %%
X_test_token_sumlist = sum(X_test_token_list,[])

X_test_unique_tokens = set(X_test_token_sumlist)
print('The unique number of words in the training dataset is: {}'.format(len(X_test_unique_tokens)))
# Out:
# The unique number of words in the training dataset is: 13677

# %% [markdown]
# ### Training Word2Vec Model - 100D, 200D, 300D

# %%
from time import time
t = time()

w2v_model100 = gensim.models.Word2Vec(X_train_token_list, sg=1, min_count=1, size = 100)

print('Time to train the model: {} mins'.format(round((time() - t) / 60, 2)))

# %%
w2v_model100.train(X_train_token_list, total_examples=w2v_model100.corpus_count, epochs=w2v_model100.epochs)

# %%
w2v_model100.save('data/w2v100.model')
w2v_model100 = gensim.models.Word2Vec.load('data/w2v100.model')

# %%
#create average vector for train and test from model; return list of numpy arrays are then stacked 

X_train_w2v100 = np.concatenate([avg_word_vectors(sentence, w2v_model100, 100) for sentence in X_train_token_list])
X_val_w2v100 = np.concatenate([avg_word_vectors(sentence, w2v_model100, 100) for sentence in X_val_token_list])

with open('data/mean_w2v_vectors.pkl', 'wb') as f:
	pickle.dump([X_train_w2v100, X_val_w2v100], f)

# %%
## W2V 200 dimension model:

# %%
w2v_model200 = gensim.models.Word2Vec(X_train_token_list, sg=1, min_count=1, size = 200)

# %%
w2v_model200.train(X_train_token_list, total_examples=w2v_model200.corpus_count, epochs=w2v_model200.epochs)

# %%
w2v_model200.save('data/w2v_200d.model')
w2v_model200 = gensim.models.Word2Vec.load('data/w2v_200d.model')

# %%
#create average vector for train and test from model; return list of numpy arrays are then stacked
X_train_w2v200 = np.concatenate([avg_word_vectors(sentence, w2v_model200, 200) for sentence in X_train_token_list])
X_val_w2v200 = np.concatenate([avg_word_vectors(sentence, w2v_model200, 200) for sentence in X_val_token_list])

# %%
with open('data/mean_w2v_vectors200.pkl', 'wb') as f:
	pickle.dump([X_train_w2v200, X_val_w2v200], f)

# %%
## W2V 300 dimension model:

# %%
w2v_model300 = gensim.models.Word2Vec(X_train_token_list, sg=1, min_count=1, size = 300)

# %%
w2v_model300.train(X_train_token_list, total_examples=w2v_model300.corpus_count, epochs=w2v_model300.epochs)

# %%
w2v_model300.save('data/w2v_300d.model')
w2v_model300 = gensim.models.Word2Vec.load('data/w2v_300d.model')

# %%
#create average vector for train and test from model; return list of numpy arrays are then stacked 

X_train_w2v300 = np.concatenate([avg_word_vectors(sentence, w2v_model300, 300) for sentence in X_train_token_list])
X_val_w2v300 = np.concatenate([avg_word_vectors(sentence, w2v_model300, 300) for sentence in X_val_token_list])

with open('data/mean_w2v_vectors300.pkl', 'wb') as f:
	pickle.dump([X_train_w2v300, X_val_w2v300], f)

# %% [markdown]
# ## Classification with Trained Word2Vec Embeddings - 100D

# %%
with open('data/mean_w2v_vectors.pkl', 'rb') as f:
    X_train_w2v100, X_val_w2v100 = pickle.load(f)

# %%
classifier_list = [('LogisticRegression', LogisticRegression(random_state = 10)),
                   ('SVM', SVC(gamma='auto', probability = True, random_state = 10)),
                    ('RandomForest', RandomForestClassifier(random_state = 10)),
                    ('AdaBoost', AdaBoostClassifier(random_state=10)),
                    ('XGBooster', XGBClassifier(random_state=10))]

# %%
w2v_model_results1 = mean_embedding_compare_classification(X_train_w2v100, y_train, X_val_w2v100, y_val, classifier_list)
w2v_model_results1
# Out:
#                       LogisticRegression   SVM  RandomForest  AdaBoost  \
# Train Accuracy                      0.94  0.93          0.99      0.94
# Train F1                            0.36  0.06          0.94      0.45
# Train Precision                     0.72  1.00          1.00      0.66
# Train Recall                        0.24  0.03          0.90      0.35
# Validation Accuracy                 0.94  0.93          0.95      0.94
# Validation F1                       0.35  0.05          0.46      0.41
# Validation Precision                0.68  1.00          0.86      0.62
# Validation Recall                   0.24  0.03          0.32      0.31
#
#                       XGBooster
# Train Accuracy             0.95
# Train F1                   0.49
# Train Precision            0.80
# Train Recall               0.35
# Validation Accuracy        0.94
# Validation F1              0.41
# Validation Precision       0.71
# Validation Recall          0.28

# %%
w2v_model_results5 = mean_embedding_compare_classification(X_train_w2v100, y_train, X_val_w2v100, y_val, 
                                                           classifier_list, sampling = 'smote')
w2v_model_results5
# Out:
#                       LogisticRegression   SVM  RandomForest  AdaBoost  \
# Train Accuracy                      0.84  0.81          1.00      0.84
# Train F1                            0.42  0.40          0.99      0.42
# Train Precision                     0.28  0.26          0.99      0.28
# Train Recall                        0.85  0.87          1.00      0.81
# Validation Accuracy                 0.85  0.83          0.94      0.85
# Validation F1                       0.44  0.41          0.55      0.42
# Validation Precision                0.30  0.27          0.57      0.29
# Validation Recall                   0.84  0.85          0.53      0.76
#
#                       XGBooster
# Train Accuracy             0.87
# Train F1                   0.49
# Train Precision            0.34
# Train Recall               0.87
# Validation Accuracy        0.88
# Validation F1              0.47
# Validation Precision       0.34
# Validation Recall          0.78

# %% [markdown]
# ### not working with XGBoost included

# %%
classifier_list2 = [('LogisticRegression', LogisticRegression(random_state = 10)),
                   ('SVM', SVC(gamma='auto', probability = True, random_state = 10)),
                    ('RandomForest', RandomForestClassifier(random_state = 10)),
                    ('AdaBoost', AdaBoostClassifier(random_state=10))]

# %%
w2v_model_results4 = mean_embedding_compare_classification(X_train_w2v100, y_train, X_val_w2v100, y_val, classifier_list2, 
                                      sampling = 'downsample')
w2v_model_results4

# %%
w2v_model_results3 = mean_embedding_compare_classification(X_train_w2v100, y_train, X_val_w2v100, y_val, classifier_list2, 
                                      sampling = 'upsample')
w2v_model_results3

# %% [markdown]
# ## Classification with w2v Embeddings - 300D:

# %%
with open('data/mean_w2v_vectors.pkl', 'rb') as f:
    X_train_w2v300, X_val_w2v300 = pickle.load(f)

# %%
w2v300_model_results1 = mean_embedding_compare_classification(X_train_w2v300, y_train, 
                                                              X_val_w2v300, y_val, classifier_list)
w2v300_model_results1
# Out:
#                       LogisticRegression   SVM  RandomForest  AdaBoost  \
# Train Accuracy                      0.94  0.93          0.99      0.94
# Train F1                            0.36  0.06          0.94      0.45
# Train Precision                     0.72  1.00          1.00      0.66
# Train Recall                        0.24  0.03          0.90      0.35
# Validation Accuracy                 0.94  0.93          0.95      0.94
# Validation F1                       0.35  0.05          0.46      0.41
# Validation Precision                0.68  1.00          0.86      0.62
# Validation Recall                   0.24  0.03          0.32      0.31
#
#                       XGBooster
# Train Accuracy             0.95
# Train F1                   0.49
# Train Precision            0.80
# Train Recall               0.35
# Validation Accuracy        0.94
# Validation F1              0.41
# Validation Precision       0.71
# Validation Recall          0.28

# %%
w2v300_model_results5 = mean_embedding_compare_classification(X_train_w2v300, y_train, X_val_w2v300, y_val, classifier_list, 
                                      sampling = 'smote')

w2v300_model_results5
# Out:
#                       LogisticRegression   SVM  RandomForest  AdaBoost  \
# Train Accuracy                      0.84  0.81          1.00      0.84
# Train F1                            0.42  0.40          0.99      0.42
# Train Precision                     0.28  0.26          0.99      0.28
# Train Recall                        0.85  0.87          1.00      0.81
# Validation Accuracy                 0.85  0.83          0.94      0.85
# Validation F1                       0.44  0.41          0.55      0.42
# Validation Precision                0.30  0.27          0.57      0.29
# Validation Recall                   0.84  0.85          0.53      0.76
#
#                       XGBooster
# Train Accuracy             0.87
# Train F1                   0.49
# Train Precision            0.34
# Train Recall               0.87
# Validation Accuracy        0.88
# Validation F1              0.47
# Validation Precision       0.34
# Validation Recall          0.78

# %% [markdown]
# #  GLoVe: Transfer Learning with Pre-Trained Word Embeddings

# %% [markdown]
# ## Preparing Mean Word Embeddings

# %%
#Glove Twitter databse with 100 dimensions

# %%
glove_input_file = 'data/glove.twitter.27B.100d.txt'
glove_output_file = 'data/glove100.txt.word2vec'
glove2word2vec(glove_input_file, glove_output_file)

# %%
glove100_model = KeyedVectors.load_word2vec_format('data/glove.txt.word2vec', binary=False)

# %%
X_train_glove100 = np.concatenate([avg_word_vectors(sentence, glove_model, 100) for sentence in X_train_token_list])
X_val_glove100 = np.concatenate([avg_word_vectors(sentence, glove_model, 100) for sentence in X_val_token_list])

# %%
with open('data/mean_glove_vectors100.pkl', 'wb') as f:
	pickle.dump([X_train_glove100, X_val_glove100], f)

# %%
#Glove Twitter databse with 200 dimensions

# %%
glove_input_file = 'data/glove.twitter.27B.200d.txt'
glove_output_file = 'data/glove200.txt.word2vec'
glove2word2vec(glove_input_file, glove_output_file)

# %%
glove200_model = KeyedVectors.load_word2vec_format('data/glove200.txt.word2vec', binary=False)

# %%
X_train_glove200 = np.concatenate([avg_word_vectors(sentence, glove200_model, 200) for sentence in X_train_token_list])
X_val_glove200 = np.concatenate([avg_word_vectors(sentence, glove200_model, 200) for sentence in X_val_token_list])

# %%
with open('data/mean_glove_vectors200.pkl', 'wb') as f:
	pickle.dump([X_train_glove200, X_val_glove200], f)

# %% [markdown]
# ## Classification with GLoVe 100 dimensions:

# %%
with open('data/mean_glove_vectors100.pkl', 'rb') as f:
    X_train_glove100, X_val_glove100 = pickle.load(f)

# %%
glove100_results1 = mean_embedding_compare_classification(X_train_glove100, y_train, X_val_glove100, 
                                                          y_val, classifier_list)
glove100_results1
# Out:
#                       LogisticRegression   SVM  RandomForest  AdaBoost  \
# Train Accuracy                      0.94  0.93          0.99      0.94
# Train F1                            0.44  0.04          0.94      0.48
# Train Precision                     0.68  0.94          1.00      0.64
# Train Recall                        0.33  0.02          0.89      0.38
# Validation Accuracy                 0.94  0.93          0.94      0.94
# Validation F1                       0.41  0.03          0.42      0.45
# Validation Precision                0.65  1.00          0.79      0.57
# Validation Recall                   0.30  0.02          0.29      0.36
#
#                       XGBooster
# Train Accuracy             0.95
# Train F1                   0.52
# Train Precision            0.81
# Train Recall               0.38
# Validation Accuracy        0.94
# Validation F1              0.44
# Validation Precision       0.72
# Validation Recall          0.32

# %%
glove100_results5 = mean_embedding_compare_classification(X_train_glove100, y_train, X_val_glove100, 
                                                          y_val, classifier_list, sampling = 'smote')
glove100_results5
# Out:
#                       LogisticRegression   SVM  RandomForest  AdaBoost  \
# Train Accuracy                      0.86  0.86          1.00      0.86
# Train F1                            0.47  0.47          0.99      0.44
# Train Precision                     0.32  0.32          0.99      0.31
# Train Recall                        0.86  0.86          1.00      0.79
# Validation Accuracy                 0.86  0.86          0.94      0.85
# Validation F1                       0.45  0.46          0.56      0.41
# Validation Precision                0.31  0.32          0.57      0.28
# Validation Recall                   0.82  0.83          0.56      0.75
#
#                       XGBooster
# Train Accuracy             0.89
# Train F1                   0.53
# Train Precision            0.39
# Train Recall               0.87
# Validation Accuracy        0.88
# Validation F1              0.48
# Validation Precision       0.35
# Validation Recall          0.79

# %%
mean_embedding_compare_classification2(X_train_glove100, y_train, X_val_glove100, y_val, classifier_list, 
                                      sampling = 'upsample')

# %%
mean_embedding_compare_classification2(X_train_glove100, y_train, X_val_glove100, y_val, classifier_list, 
                                      sampling = 'downsample')

# %% [markdown]
# ## Classification with GLoVe 200 dimensions:

# %%
with open('data/mean_glove_vectors200.pkl', 'rb') as f:
    X_train_glove200, X_val_glove200 = pickle.load(f)

# %%
glove200_results1 = mean_embedding_compare_classification(X_train_glove200, y_train, X_val_glove200, 
                                                          y_val, classifier_list)
glove200_results1
# Out:
#                       LogisticRegression   SVM  RandomForest  AdaBoost  \
# Train Accuracy                      0.95  0.93          0.99      0.94
# Train F1                            0.49  0.10          0.94      0.50
# Train Precision                     0.72  1.00          1.00      0.64
# Train Recall                        0.37  0.05          0.89      0.41
# Validation Accuracy                 0.94  0.93          0.94      0.94
# Validation F1                       0.47  0.08          0.39      0.48
# Validation Precision                0.69  1.00          0.83      0.61
# Validation Recall                   0.35  0.04          0.26      0.40
#
#                       XGBooster
# Train Accuracy             0.95
# Train F1                   0.54
# Train Precision            0.84
# Train Recall               0.40
# Validation Accuracy        0.95
# Validation F1              0.46
# Validation Precision       0.74
# Validation Recall          0.34

# %%
glove200_results5 = mean_embedding_compare_classification(X_train_glove200, y_train, X_val_glove200, 
                                                          y_val, classifier_list, sampling = 'smote')
glove200_results5
# Out:
#                       LogisticRegression   SVM  RandomForest  AdaBoost  \
# Train Accuracy                      0.88  0.87          1.00      0.86
# Train F1                            0.50  0.49          1.00      0.44
# Train Precision                     0.35  0.34          0.99      0.31
# Train Recall                        0.86  0.86          1.00      0.78
# Validation Accuracy                 0.88  0.87          0.93      0.85
# Validation F1                       0.48  0.48          0.50      0.40
# Validation Precision                0.34  0.34          0.52      0.28
# Validation Recall                   0.82  0.84          0.49      0.71
#
#                       XGBooster
# Train Accuracy             0.90
# Train F1                   0.55
# Train Precision            0.40
# Train Recall               0.86
# Validation Accuracy        0.88
# Validation F1              0.47
# Validation Precision       0.34
# Validation Recall          0.77
