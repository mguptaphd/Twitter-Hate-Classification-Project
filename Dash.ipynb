# %%
# !pip install dash
# !pip install dash-renderer
# !pip install dash-html-components
# !pip install dash-core-components
# !pip install plotly
# Out:
# Collecting dash
#   Downloading https://files.pythonhosted.org/packages/a2/23/16356a67a3c5f2fecd40aeb7e921c19097c2c40bce6ba0cb6f7bbf1c60dc/dash-1.0.2.tar.gz (56kB)
#     100% |████████████████████████████████| 61kB 1.7MB/s ta 0:00:01
# Requirement already satisfied: Flask>=1.0.2 in /Users/flatironschool/anaconda3/lib/python3.7/site-packages (from dash) (1.0.2)
# Collecting PyYAML>=5.1.1 (from dash)
#   Downloading https://files.pythonhosted.org/packages/e3/e8/b3212641ee2718d556df0f23f78de8303f068fe29cdaa7a91018849582fe/PyYAML-5.1.2.tar.gz (265kB)
#     100% |████████████████████████████████| 266kB 4.1MB/s ta 0:00:01
# Collecting flask-compress (from dash)
#   Downloading https://files.pythonhosted.org/packages/0e/2a/378bd072928f6d92fd8c417d66b00c757dc361c0405a46a0134de6fd323d/Flask-Compress-1.4.0.tar.gz
# Requirement already satisfied: plotly in /Users/flatironschool/anaconda3/lib/python3.7/site-packages (from dash) (3.10.0)
# Collecting dash_renderer==1.0.0 (from dash)
#   Downloading https://files.pythonhosted.org/packages/c4/b2/59bfd95cce1c105fd70666eaa703b2040a4e039071b95238e9ef9c34eebc/dash_renderer-1.0.0.tar.gz (2.3MB)
#     100% |████████████████████████████████| 2.3MB 1.4MB/s ta 0:00:011
# Collecting dash-core-components==1.0.0 (from dash)
#   Downloading https://files.pythonhosted.org/packages/a5/cd/e16679d871dd629cf42e6f7a80ae9204e4f06ba92d4ae8a0bafec1355ec5/dash_core_components-1.0.0.tar.gz (2.1MB)
#     100% |████████████████████████████████| 2.1MB 1.9MB/s ta 0:00:01    45% |██████████████▊                 | 972kB 2.4MB/s eta 0:00:01
# Collecting dash-html-components==1.0.0 (from dash)
#   Downloading https://files.pythonhosted.org/packages/7b/91/d0d575b98b5c27094ae557cceb0eed331235abb9910b3bf37407ca888052/dash_html_components-1.0.0.tar.gz (182kB)
#     100% |████████████████████████████████| 184kB 4.1MB/s ta 0:00:011
# Collecting dash-table==4.0.2 (from dash)
#   Downloading https://files.pythonhosted.org/packages/d3/5a/f7ef2e157bd3f75888b0c93d8cf368371cdde64fdfc7f8eda68af9d698e9/dash_table-4.0.2.tar.gz (540kB)
#     100% |████████████████████████████████| 542kB 1.4MB/s ta 0:00:01
# Requirement already satisfied: Jinja2>=2.10 in /Users/flatironschool/anaconda3/lib/python3.7/site-packages (from Flask>=1.0.2->dash) (2.10)
# Requirement already satisfied: Werkzeug>=0.14 in /Users/flatironschool/anaconda3/lib/python3.7/site-packages (from Flask>=1.0.2->dash) (0.14.1)
# Requirement already satisfied: itsdangerous>=0.24 in /Users/flatironschool/anaconda3/lib/python3.7/site-packages (from Flask>=1.0.2->dash) (1.1.0)
# Requirement already satisfied: click>=5.1 in /Users/flatironschool/anaconda3/lib/python3.7/site-packages (from Flask>=1.0.2->dash) (7.0)
# Requirement already satisfied: requests in /Users/flatironschool/anaconda3/lib/python3.7/site-packages (from plotly->dash) (2.21.0)
# Requirement already satisfied: pytz in /Users/flatironschool/anaconda3/lib/python3.7/site-packages (from plotly->dash) (2018.9)
# Requirement already satisfied: decorator>=4.0.6 in /Users/flatironschool/anaconda3/lib/python3.7/site-packages (from plotly->dash) (4.4.0)
# Requirement already satisfied: six in /Users/flatironschool/anaconda3/lib/python3.7/site-packages (from plotly->dash) (1.12.0)
# Requirement already satisfied: nbformat>=4.2 in /Users/flatironschool/anaconda3/lib/python3.7/site-packages (from plotly->dash) (4.4.0)
# Requirement already satisfied: retrying>=1.3.3 in /Users/flatironschool/anaconda3/lib/python3.7/site-packages (from plotly->dash) (1.3.3)
# Requirement already satisfied: MarkupSafe>=0.23 in /Users/flatironschool/anaconda3/lib/python3.7/site-packages (from Jinja2>=2.10->Flask>=1.0.2->dash) (1.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/flatironschool/anaconda3/lib/python3.7/site-packages (from requests->plotly->dash) (2019.3.9)
# Requirement already satisfied: idna<2.9,>=2.5 in /Users/flatironschool/anaconda3/lib/python3.7/site-packages (from requests->plotly->dash) (2.8)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /Users/flatironschool/anaconda3/lib/python3.7/site-packages (from requests->plotly->dash) (1.24.1)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /Users/flatironschool/anaconda3/lib/python3.7/site-packages (from requests->plotly->dash) (3.0.4)
# Requirement already satisfied: ipython-genutils in /Users/flatironschool/anaconda3/lib/python3.7/site-packages (from nbformat>=4.2->plotly->dash) (0.2.0)
# Requirement already satisfied: jupyter-core in /Users/flatironschool/anaconda3/lib/python3.7/site-packages (from nbformat>=4.2->plotly->dash) (4.4.0)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /Users/flatironschool/anaconda3/lib/python3.7/site-packages (from nbformat>=4.2->plotly->dash) (3.0.1)
# Requirement already satisfied: traitlets>=4.1 in /Users/flatironschool/anaconda3/lib/python3.7/site-packages (from nbformat>=4.2->plotly->dash) (4.3.2)
# Requirement already satisfied: attrs>=17.4.0 in /Users/flatironschool/anaconda3/lib/python3.7/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2->plotly->dash) (19.1.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in /Users/flatironschool/anaconda3/lib/python3.7/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2->plotly->dash) (0.14.11)
# Requirement already satisfied: setuptools in /Users/flatironschool/anaconda3/lib/python3.7/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2->plotly->dash) (41.0.1)
# Building wheels for collected packages: dash, PyYAML, flask-compress, dash-renderer, dash-core-components, dash-html-components, dash-table
#   Building wheel for dash (setup.py) ... done
#   Stored in directory: /Users/flatironschool/Library/Caches/pip/wheels/95/a3/cb/76c6b775ba23f12b40b0ba69a11afdb8157598688341936bd5
#   Building wheel for PyYAML (setup.py) ... done
#   Stored in directory: /Users/flatironschool/Library/Caches/pip/wheels/d9/45/dd/65f0b38450c47cf7e5312883deb97d065e030c5cca0a365030
#   Building wheel for flask-compress (setup.py) ... done
#   Stored in directory: /Users/flatironschool/Library/Caches/pip/wheels/96/32/88/a1f6d9dd3c29570ab3a8acc0d556b3b20abcf3c623c868ce0a
#   Building wheel for dash-renderer (setup.py) ... done
#   Stored in directory: /Users/flatironschool/Library/Caches/pip/wheels/e1/ec/40/f23ca8bba2cc56ffb3a279a660d1df7c6e1fa2557a664b660c
#   Building wheel for dash-core-components (setup.py) ... done
#   Stored in directory: /Users/flatironschool/Library/Caches/pip/wheels/4c/fa/04/dc1340493d92d3fe3c906be9155c4ed750e003578328998ff8
#   Building wheel for dash-html-components (setup.py) ... done
#   Stored in directory: /Users/flatironschool/Library/Caches/pip/wheels/a4/37/96/cb58a2cadbe39fd074c3cace280a576f6ea860a4bdf1703763
#   Building wheel for dash-table (setup.py) ... done
#   Stored in directory: /Users/flatironschool/Library/Caches/pip/wheels/1c/88/cb/2f0192c8391997c910f2f3f75020346bf4ecf86a2448109a14
# Successfully built dash PyYAML flask-compress dash-renderer dash-core-components dash-html-components dash-table
# awscli 1.16.195 has requirement PyYAML<=5.1,>=3.10; python_version != "2.6", but you'll have pyyaml 5.1.2 which is incompatible.
# Installing collected packages: PyYAML, flask-compress, dash-renderer, dash-core-components, dash-html-components, dash-table, dash
#   Found existing installation: PyYAML 5.1
# Cannot uninstall 'PyYAML'. It is a distutils installed project and thus we cannot accurately determine which files belong to it which would lead to only a partial uninstall.
# Collecting dash-renderer
# Installing collected packages: dash-renderer
# Successfully installed dash-renderer-1.0.0
# Collecting dash-html-components
# Installing collected packages: dash-html-components
# Successfully installed dash-html-components-1.0.0
# Collecting dash-core-components
# Installing collected packages: dash-core-components
# Successfully installed dash-core-components-1.0.0
# Requirement already satisfied: plotly in /Users/flatironschool/anaconda3/lib/python3.7/site-packages (3.10.0)
# Requirement already satisfied: pytz in /Users/flatironschool/anaconda3/lib/python3.7/site-packages (from plotly) (2018.9)
# Requirement already satisfied: nbformat>=4.2 in /Users/flatironschool/anaconda3/lib/python3.7/site-packages (from plotly) (4.4.0)
# Requirement already satisfied: retrying>=1.3.3 in /Users/flatironschool/anaconda3/lib/python3.7/site-packages (from plotly) (1.3.3)
# Requirement already satisfied: six in /Users/flatironschool/anaconda3/lib/python3.7/site-packages (from plotly) (1.12.0)
# Requirement already satisfied: decorator>=4.0.6 in /Users/flatironschool/anaconda3/lib/python3.7/site-packages (from plotly) (4.4.0)
# Requirement already satisfied: requests in /Users/flatironschool/anaconda3/lib/python3.7/site-packages (from plotly) (2.21.0)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /Users/flatironschool/anaconda3/lib/python3.7/site-packages (from nbformat>=4.2->plotly) (3.0.1)
# Requirement already satisfied: jupyter-core in /Users/flatironschool/anaconda3/lib/python3.7/site-packages (from nbformat>=4.2->plotly) (4.4.0)
# Requirement already satisfied: traitlets>=4.1 in /Users/flatironschool/anaconda3/lib/python3.7/site-packages (from nbformat>=4.2->plotly) (4.3.2)
# Requirement already satisfied: ipython-genutils in /Users/flatironschool/anaconda3/lib/python3.7/site-packages (from nbformat>=4.2->plotly) (0.2.0)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /Users/flatironschool/anaconda3/lib/python3.7/site-packages (from requests->plotly) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in /Users/flatironschool/anaconda3/lib/python3.7/site-packages (from requests->plotly) (2.8)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /Users/flatironschool/anaconda3/lib/python3.7/site-packages (from requests->plotly) (1.24.1)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/flatironschool/anaconda3/lib/python3.7/site-packages (from requests->plotly) (2019.3.9)
# Requirement already satisfied: attrs>=17.4.0 in /Users/flatironschool/anaconda3/lib/python3.7/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2->plotly) (19.1.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in /Users/flatironschool/anaconda3/lib/python3.7/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2->plotly) (0.14.11)
# Requirement already satisfied: setuptools in /Users/flatironschool/anaconda3/lib/python3.7/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2->plotly) (41.0.1)

# %%
# !pip install dash==1.0.2  # The core dash backend
# !pip install dash-daq==0.1.0  # DAQ components (newly open-sourced!)
# Out:
# Collecting dash==1.0.2
# Requirement already satisfied: plotly in /Users/flatironschool/anaconda3/lib/python3.7/site-packages (from dash==1.0.2) (3.10.0)
# Requirement already satisfied: dash-html-components==1.0.0 in /Users/flatironschool/anaconda3/lib/python3.7/site-packages (from dash==1.0.2) (1.0.0)
# Collecting dash-table==4.0.2 (from dash==1.0.2)
# Collecting flask-compress (from dash==1.0.2)
# Collecting PyYAML>=5.1.1 (from dash==1.0.2)
# Requirement already satisfied: dash-renderer==1.0.0 in /Users/flatironschool/anaconda3/lib/python3.7/site-packages (from dash==1.0.2) (1.0.0)
# Requirement already satisfied: dash-core-components==1.0.0 in /Users/flatironschool/anaconda3/lib/python3.7/site-packages (from dash==1.0.2) (1.0.0)
# Requirement already satisfied: Flask>=1.0.2 in /Users/flatironschool/anaconda3/lib/python3.7/site-packages (from dash==1.0.2) (1.0.2)
# Requirement already satisfied: nbformat>=4.2 in /Users/flatironschool/anaconda3/lib/python3.7/site-packages (from plotly->dash==1.0.2) (4.4.0)
# Requirement already satisfied: pytz in /Users/flatironschool/anaconda3/lib/python3.7/site-packages (from plotly->dash==1.0.2) (2018.9)
# Requirement already satisfied: six in /Users/flatironschool/anaconda3/lib/python3.7/site-packages (from plotly->dash==1.0.2) (1.12.0)
# Requirement already satisfied: requests in /Users/flatironschool/anaconda3/lib/python3.7/site-packages (from plotly->dash==1.0.2) (2.21.0)
# Requirement already satisfied: decorator>=4.0.6 in /Users/flatironschool/anaconda3/lib/python3.7/site-packages (from plotly->dash==1.0.2) (4.4.0)
# Requirement already satisfied: retrying>=1.3.3 in /Users/flatironschool/anaconda3/lib/python3.7/site-packages (from plotly->dash==1.0.2) (1.3.3)
# Requirement already satisfied: click>=5.1 in /Users/flatironschool/anaconda3/lib/python3.7/site-packages (from Flask>=1.0.2->dash==1.0.2) (7.0)
# Requirement already satisfied: itsdangerous>=0.24 in /Users/flatironschool/anaconda3/lib/python3.7/site-packages (from Flask>=1.0.2->dash==1.0.2) (1.1.0)
# Requirement already satisfied: Werkzeug>=0.14 in /Users/flatironschool/anaconda3/lib/python3.7/site-packages (from Flask>=1.0.2->dash==1.0.2) (0.14.1)
# Requirement already satisfied: Jinja2>=2.10 in /Users/flatironschool/anaconda3/lib/python3.7/site-packages (from Flask>=1.0.2->dash==1.0.2) (2.10)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /Users/flatironschool/anaconda3/lib/python3.7/site-packages (from nbformat>=4.2->plotly->dash==1.0.2) (3.0.1)
# Requirement already satisfied: traitlets>=4.1 in /Users/flatironschool/anaconda3/lib/python3.7/site-packages (from nbformat>=4.2->plotly->dash==1.0.2) (4.3.2)
# Requirement already satisfied: ipython-genutils in /Users/flatironschool/anaconda3/lib/python3.7/site-packages (from nbformat>=4.2->plotly->dash==1.0.2) (0.2.0)
# Requirement already satisfied: jupyter-core in /Users/flatironschool/anaconda3/lib/python3.7/site-packages (from nbformat>=4.2->plotly->dash==1.0.2) (4.4.0)
# Requirement already satisfied: idna<2.9,>=2.5 in /Users/flatironschool/anaconda3/lib/python3.7/site-packages (from requests->plotly->dash==1.0.2) (2.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /Users/flatironschool/anaconda3/lib/python3.7/site-packages (from requests->plotly->dash==1.0.2) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/flatironschool/anaconda3/lib/python3.7/site-packages (from requests->plotly->dash==1.0.2) (2019.3.9)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /Users/flatironschool/anaconda3/lib/python3.7/site-packages (from requests->plotly->dash==1.0.2) (1.24.1)
# Requirement already satisfied: MarkupSafe>=0.23 in /Users/flatironschool/anaconda3/lib/python3.7/site-packages (from Jinja2>=2.10->Flask>=1.0.2->dash==1.0.2) (1.1.1)
# Requirement already satisfied: attrs>=17.4.0 in /Users/flatironschool/anaconda3/lib/python3.7/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2->plotly->dash==1.0.2) (19.1.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in /Users/flatironschool/anaconda3/lib/python3.7/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2->plotly->dash==1.0.2) (0.14.11)
# Requirement already satisfied: setuptools in /Users/flatironschool/anaconda3/lib/python3.7/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2->plotly->dash==1.0.2) (41.0.1)
# awscli 1.16.195 has requirement PyYAML<=5.1,>=3.10; python_version != "2.6", but you'll have pyyaml 5.1.2 which is incompatible.
# Installing collected packages: dash-table, flask-compress, PyYAML, dash
#   Found existing installation: PyYAML 5.1
# Cannot uninstall 'PyYAML'. It is a distutils installed project and thus we cannot accurately determine which files belong to it which would lead to only a partial uninstall.
# Collecting dash-daq==0.1.0
#   Downloading https://files.pythonhosted.org/packages/8c/90/6c1405732316ad625ad6c6498d222a8ab8ef6183b2b60d8688b272bbe727/dash_daq-0.1.0.tar.gz (775kB)
#     100% |████████████████████████████████| 778kB 2.7MB/s ta 0:00:011   25% |████████                        | 194kB 2.2MB/s eta 0:00:01
# Building wheels for collected packages: dash-daq
#   Building wheel for dash-daq (setup.py) ... done
#   Stored in directory: /Users/flatironschool/Library/Caches/pip/wheels/c0/ed/73/bf2186ecfdc110a63a45ec69b8fc0e2ad1fcc7e442dac1225d
# Successfully built dash-daq
# Installing collected packages: dash-daq
# Successfully installed dash-daq-0.1.0

# %%
import dash
import dash_core_components as dcc
import dash_html_components as html
from dash.dependencies import Input, Output
from sklearn.externals import joblib
import plotly.graph_objs as go

app = dash.Dash()

if __name__ == '__main__':
    app.run_server(debug=True)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-11-201b6af6253a> in <module>
# ----> 1 import dash
#       2 import dash_core_components as dcc
#       3 import dash_html_components as html
#       4 from dash.dependencies import Input, Output
#       5 from sklearn.externals import joblib
#
# ModuleNotFoundError: No module named 'dash'

# %%
# !pip install dash==0.21.1  
# !pip install dash-renderer==0.13.0  
# !pip install dash-html-components==0.11.0
# !pip install dash-core-components==0.23.0  
# !pip install plotly --upgrade
# Out:
# Collecting dash==0.21.1
#   Downloading https://files.pythonhosted.org/packages/db/08/5bc503722a3d430ed01c5c75d754c8cdae6f6c2d83c10b48987a6a41af02/dash-0.21.1.tar.gz
# Requirement already satisfied: Flask>=0.12 in /Users/flatironschool/anaconda3/lib/python3.7/site-packages (from dash==0.21.1) (1.0.2)
# Requirement already satisfied: flask-compress in /Users/flatironschool/anaconda3/lib/python3.7/site-packages (from dash==0.21.1) (1.4.0)
# Requirement already satisfied: plotly in /Users/flatironschool/anaconda3/lib/python3.7/site-packages (from dash==0.21.1) (3.10.0)
# Requirement already satisfied: Jinja2>=2.10 in /Users/flatironschool/anaconda3/lib/python3.7/site-packages (from Flask>=0.12->dash==0.21.1) (2.10)
# Requirement already satisfied: click>=5.1 in /Users/flatironschool/anaconda3/lib/python3.7/site-packages (from Flask>=0.12->dash==0.21.1) (7.0)
# Requirement already satisfied: Werkzeug>=0.14 in /Users/flatironschool/anaconda3/lib/python3.7/site-packages (from Flask>=0.12->dash==0.21.1) (0.14.1)
# Requirement already satisfied: itsdangerous>=0.24 in /Users/flatironschool/anaconda3/lib/python3.7/site-packages (from Flask>=0.12->dash==0.21.1) (1.1.0)
# Requirement already satisfied: nbformat>=4.2 in /Users/flatironschool/anaconda3/lib/python3.7/site-packages (from plotly->dash==0.21.1) (4.4.0)
# Requirement already satisfied: pytz in /Users/flatironschool/anaconda3/lib/python3.7/site-packages (from plotly->dash==0.21.1) (2018.9)
# Requirement already satisfied: requests in /Users/flatironschool/anaconda3/lib/python3.7/site-packages (from plotly->dash==0.21.1) (2.21.0)
# Requirement already satisfied: retrying>=1.3.3 in /Users/flatironschool/anaconda3/lib/python3.7/site-packages (from plotly->dash==0.21.1) (1.3.3)
# Requirement already satisfied: decorator>=4.0.6 in /Users/flatironschool/anaconda3/lib/python3.7/site-packages (from plotly->dash==0.21.1) (4.4.0)
# Requirement already satisfied: six in /Users/flatironschool/anaconda3/lib/python3.7/site-packages (from plotly->dash==0.21.1) (1.12.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /Users/flatironschool/anaconda3/lib/python3.7/site-packages (from Jinja2>=2.10->Flask>=0.12->dash==0.21.1) (1.1.1)
# Requirement already satisfied: traitlets>=4.1 in /Users/flatironschool/anaconda3/lib/python3.7/site-packages (from nbformat>=4.2->plotly->dash==0.21.1) (4.3.2)
# Requirement already satisfied: jupyter-core in /Users/flatironschool/anaconda3/lib/python3.7/site-packages (from nbformat>=4.2->plotly->dash==0.21.1) (4.4.0)
# Requirement already satisfied: ipython-genutils in /Users/flatironschool/anaconda3/lib/python3.7/site-packages (from nbformat>=4.2->plotly->dash==0.21.1) (0.2.0)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /Users/flatironschool/anaconda3/lib/python3.7/site-packages (from nbformat>=4.2->plotly->dash==0.21.1) (3.0.1)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/flatironschool/anaconda3/lib/python3.7/site-packages (from requests->plotly->dash==0.21.1) (2019.3.9)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /Users/flatironschool/anaconda3/lib/python3.7/site-packages (from requests->plotly->dash==0.21.1) (3.0.4)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /Users/flatironschool/anaconda3/lib/python3.7/site-packages (from requests->plotly->dash==0.21.1) (1.24.1)
# Requirement already satisfied: idna<2.9,>=2.5 in /Users/flatironschool/anaconda3/lib/python3.7/site-packages (from requests->plotly->dash==0.21.1) (2.8)
# Requirement already satisfied: attrs>=17.4.0 in /Users/flatironschool/anaconda3/lib/python3.7/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2->plotly->dash==0.21.1) (19.1.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in /Users/flatironschool/anaconda3/lib/python3.7/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2->plotly->dash==0.21.1) (0.14.11)
# Requirement already satisfied: setuptools in /Users/flatironschool/anaconda3/lib/python3.7/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2->plotly->dash==0.21.1) (41.0.1)
# Building wheels for collected packages: dash
#   Building wheel for dash (setup.py) ... done
#   Stored in directory: /Users/flatironschool/Library/Caches/pip/wheels/79/4e/43/d38542943cc58ce490e4f204298b511e6a22891236eb2f19e1
# Successfully built dash
# Installing collected packages: dash
# Successfully installed dash-0.21.1
# Collecting dash-renderer==0.13.0
#   Downloading https://files.pythonhosted.org/packages/98/12/8176efede4139bc31b076b0e44a0f4cb002ead600ea4fd84e2ac8afd81cc/dash_renderer-0.13.0.tar.gz (160kB)
#     100% |████████████████████████████████| 163kB 2.1MB/s ta 0:00:01
# Building wheels for collected packages: dash-renderer
#   Building wheel for dash-renderer (setup.py) ... done
#   Stored in directory: /Users/flatironschool/Library/Caches/pip/wheels/b4/b3/65/c4985d8d3394311d4b6e15c02c12dc963b28590c3048d01c77
# Successfully built dash-renderer
# Installing collected packages: dash-renderer
#   Found existing installation: dash-renderer 1.0.0
#     Uninstalling dash-renderer-1.0.0:
#       Successfully uninstalled dash-renderer-1.0.0
# Successfully installed dash-renderer-0.13.0
# Collecting dash-html-components==0.11.0
#   Downloading https://files.pythonhosted.org/packages/cd/7d/9660cc8c763f87b69301100e2f9a9c373b5a14782547b0d80e039cc3e0e3/dash_html_components-0.11.0.tar.gz
# Requirement already satisfied: dash in /Users/flatironschool/anaconda3/lib/python3.7/site-packages (from dash-html-components==0.11.0) (0.21.1)
# Requirement already satisfied: flask-compress in /Users/flatironschool/anaconda3/lib/python3.7/site-packages (from dash->dash-html-components==0.11.0) (1.4.0)
# Requirement already satisfied: Flask>=0.12 in /Users/flatironschool/anaconda3/lib/python3.7/site-packages (from dash->dash-html-components==0.11.0) (1.0.2)
# Requirement already satisfied: plotly in /Users/flatironschool/anaconda3/lib/python3.7/site-packages (from dash->dash-html-components==0.11.0) (3.10.0)
# Requirement already satisfied: Werkzeug>=0.14 in /Users/flatironschool/anaconda3/lib/python3.7/site-packages (from Flask>=0.12->dash->dash-html-components==0.11.0) (0.14.1)
# Requirement already satisfied: itsdangerous>=0.24 in /Users/flatironschool/anaconda3/lib/python3.7/site-packages (from Flask>=0.12->dash->dash-html-components==0.11.0) (1.1.0)
# Requirement already satisfied: click>=5.1 in /Users/flatironschool/anaconda3/lib/python3.7/site-packages (from Flask>=0.12->dash->dash-html-components==0.11.0) (7.0)
# Requirement already satisfied: Jinja2>=2.10 in /Users/flatironschool/anaconda3/lib/python3.7/site-packages (from Flask>=0.12->dash->dash-html-components==0.11.0) (2.10)
# Requirement already satisfied: six in /Users/flatironschool/anaconda3/lib/python3.7/site-packages (from plotly->dash->dash-html-components==0.11.0) (1.12.0)
# Requirement already satisfied: decorator>=4.0.6 in /Users/flatironschool/anaconda3/lib/python3.7/site-packages (from plotly->dash->dash-html-components==0.11.0) (4.4.0)
# Requirement already satisfied: requests in /Users/flatironschool/anaconda3/lib/python3.7/site-packages (from plotly->dash->dash-html-components==0.11.0) (2.21.0)
# Requirement already satisfied: retrying>=1.3.3 in /Users/flatironschool/anaconda3/lib/python3.7/site-packages (from plotly->dash->dash-html-components==0.11.0) (1.3.3)
# Requirement already satisfied: pytz in /Users/flatironschool/anaconda3/lib/python3.7/site-packages (from plotly->dash->dash-html-components==0.11.0) (2018.9)
# Requirement already satisfied: nbformat>=4.2 in /Users/flatironschool/anaconda3/lib/python3.7/site-packages (from plotly->dash->dash-html-components==0.11.0) (4.4.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /Users/flatironschool/anaconda3/lib/python3.7/site-packages (from Jinja2>=2.10->Flask>=0.12->dash->dash-html-components==0.11.0) (1.1.1)
# Requirement already satisfied: idna<2.9,>=2.5 in /Users/flatironschool/anaconda3/lib/python3.7/site-packages (from requests->plotly->dash->dash-html-components==0.11.0) (2.8)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/flatironschool/anaconda3/lib/python3.7/site-packages (from requests->plotly->dash->dash-html-components==0.11.0) (2019.3.9)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /Users/flatironschool/anaconda3/lib/python3.7/site-packages (from requests->plotly->dash->dash-html-components==0.11.0) (3.0.4)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /Users/flatironschool/anaconda3/lib/python3.7/site-packages (from requests->plotly->dash->dash-html-components==0.11.0) (1.24.1)
# Requirement already satisfied: ipython-genutils in /Users/flatironschool/anaconda3/lib/python3.7/site-packages (from nbformat>=4.2->plotly->dash->dash-html-components==0.11.0) (0.2.0)
# Requirement already satisfied: jupyter-core in /Users/flatironschool/anaconda3/lib/python3.7/site-packages (from nbformat>=4.2->plotly->dash->dash-html-components==0.11.0) (4.4.0)
# Requirement already satisfied: traitlets>=4.1 in /Users/flatironschool/anaconda3/lib/python3.7/site-packages (from nbformat>=4.2->plotly->dash->dash-html-components==0.11.0) (4.3.2)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /Users/flatironschool/anaconda3/lib/python3.7/site-packages (from nbformat>=4.2->plotly->dash->dash-html-components==0.11.0) (3.0.1)
# Requirement already satisfied: attrs>=17.4.0 in /Users/flatironschool/anaconda3/lib/python3.7/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2->plotly->dash->dash-html-components==0.11.0) (19.1.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in /Users/flatironschool/anaconda3/lib/python3.7/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2->plotly->dash->dash-html-components==0.11.0) (0.14.11)
# Requirement already satisfied: setuptools in /Users/flatironschool/anaconda3/lib/python3.7/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2->plotly->dash->dash-html-components==0.11.0) (41.0.1)
# Building wheels for collected packages: dash-html-components
#   Building wheel for dash-html-components (setup.py) ... done
#   Stored in directory: /Users/flatironschool/Library/Caches/pip/wheels/bb/fb/8a/96aa90e26c373598c43e7b641873c411539407a51487baf310
# Successfully built dash-html-components
# Installing collected packages: dash-html-components
#   Found existing installation: dash-html-components 1.0.0
#     Uninstalling dash-html-components-1.0.0:
#       Successfully uninstalled dash-html-components-1.0.0
# Successfully installed dash-html-components-0.11.0
# Collecting dash-core-components==0.23.0
